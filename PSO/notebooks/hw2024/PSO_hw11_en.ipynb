# %% [markdown]
# <a href="https://colab.research.google.com/github/kocurvik/edu/blob/master/PSO/notebooks/hw2024/PSO_hw11_en.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Homework Exercise 11: Color Enhancement**
#
# In this exercise your taks will be to enhance a color image. By using histogram equalization on only the V (Value) channel in the HSV (Hue Saturation Value) color space. Show the image before and after.
#
# Created by: Fatana Hasenat

# %%
# !wget https://raw.githubusercontent.com/kocurvik/edu/refs/heads/master/PSO/images/boats.jpg
# Out:
# --2024-11-27 12:55:41--  https://raw.githubusercontent.com/kocurvik/edu/refs/heads/master/PSO/images/boats.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 71285 (70K) [image/jpeg]
# Saving to: ‘boats.jpg.1’
#
# boats.jpg.1         100%[===================>]  69.61K  --.-KB/s    in 0.02s
#
# 2024-11-27 12:55:42 (3.09 MB/s) - ‘boats.jpg.1’ saved [71285/71285]

# %%
# implement here
...
