# %% [markdown]
# <a href="https://colab.research.google.com/github/kocurvik/edu/blob/master/PSO/notebooks/PSO_hw04_en.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework Exercise 4 - Adaptive Thresholding
#
# Implement the function adaptive thresholding in Numpy and OpenCV. The method should assign each pixel either the value O or 255 based on the whether the given pixel intensity is higher than the mean of the neigboring pixels in the block of size `block_size` $\times$ `block_size`. To calculate the mean consider only pixels in the image.
#
# You may use the functions from OpenCV, but not the implementation of thresholding. If your implementation is inefficient (usually due to using for cycles) you may lose some points.

# %%
import numpy as np
import cv2

def adaptive_thresholding(image, block_size):
    # implement

    return thresholded_image

# %%
# !wget https://raw.githubusercontent.com/kocurvik/edu/master/PSO/images/good_checkers.png
# !wget https://raw.githubusercontent.com/kocurvik/edu/master/PSO/images/bad_checkers.png

from matplotlib import pyplot as plt

def show(img, title=None):
  plt.imshow(img, cmap='gray', vmin=0, vmax=255)
  plt.axis('off')
  plt.title(title)
  plt.show()

img_bad = cv2.cvtColor(cv2.imread('bad_checkers.png'), cv2.COLOR_BGR2GRAY)
show(img_bad, 'Original')
show(adaptive_thresholding(img_bad, 19), 'Thresholded, block = 19')
show(adaptive_thresholding(img_bad, 121), 'Thresholded, block = 121')
show(adaptive_thresholding(img_bad, 53), 'Thresholded, block = 53')
show(adaptive_thresholding(img_bad, 47), 'Thresholded, block = 47')
# Out:
# --2023-10-17 17:01:43--  https://raw.githubusercontent.com/kocurvik/edu/master/PSO/images/good_checkers.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 159613 (156K) [image/png]
# Saving to: ‘good_checkers.png’
#
# good_checkers.png   100%[===================>] 155.87K  --.-KB/s    in 0.03s
#
# 2023-10-17 17:01:44 (4.73 MB/s) - ‘good_checkers.png’ saved [159613/159613]
#
# --2023-10-17 17:01:44--  https://raw.githubusercontent.com/kocurvik/edu/master/PSO/images/bad_checkers.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# ...
