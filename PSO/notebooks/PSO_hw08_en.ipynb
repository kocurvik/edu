# %% [markdown]
# <a href="https://colab.research.google.com/github/kocurvik/edu/blob/master/PSO/notebooks/PSO_hw08_en.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework Exercise 8 - Rectification
#
# In this exercie you should perform image rectification in the same manner as in the last exercise in cv11, but the user should be able to select the points manually.
#
# When the user clicks the image a point will be selected. Be sure to display this point onto the image. When four points are selected show a new image with the rectified result.
#
# Note that the user has to click the points in a correct order for this method to work.

# %%
# !wget https://raw.githubusercontent.com/kocurvik/edu/master/PSO/images/sign.jpg

# !pip install ipympl
from google.colab import output
output.enable_custom_widget_manager()
# %matplotlib ipympl

import cv2
import numpy as np
# Out:
# --2023-12-05 16:13:38--  https://raw.githubusercontent.com/kocurvik/edu/master/PSO/images/sign.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 76828 (75K) [image/jpeg]
# Saving to: ‘sign.jpg’
#
# sign.jpg            100%[===================>]  75.03K  --.-KB/s    in 0.003s
#
# 2023-12-05 16:13:38 (25.9 MB/s) - ‘sign.jpg’ saved [76828/76828]
#
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.6/511.6 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 28.1 MB/s eta 0:00:00
# ...

# %%
...
# Out:
# Already selected all - starting from first point
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
