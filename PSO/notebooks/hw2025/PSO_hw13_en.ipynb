# %% [markdown]
# <a href="https://colab.research.google.com/github/kocurvik/edu/blob/master/PSO/notebooks/hw2025/PSO_hw13_en.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework 13 - Image Posterization
#
# In this exercise use k-means algorithm to reduce the number of colors in an image to k by changing all pixels that belong to a cluster to the color of the corresponding center. Do this by implementing the function `posterize`, which returns the posterized image.

# %%
# !wget https://raw.githubusercontent.com/kocurvik/edu/master/PSO/images/car.jpg
# Out:
# --2024-12-18 11:22:53--  https://raw.githubusercontent.com/kocurvik/edu/master/PSO/images/car.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 143706 (140K) [image/jpeg]
# Saving to: ‘car.jpg’
#
# car.jpg             100%[===================>] 140.34K  --.-KB/s    in 0.03s
#
# 2024-12-18 11:22:53 (4.38 MB/s) - ‘car.jpg’ saved [143706/143706]

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

def posterize(img, k):
    ...

# %%
img = cv2.imread('car.jpg')
plt.imshow(img[:, :, ::-1])
plt.axis("off")
plt.title("Original")
plt.show()


for k in [3, 5, 10, 20, 30]:
  p = posterize(img, k)
  plt.imshow(p[:, :, ::-1])
  plt.axis("off")
  plt.title(f"Posterized with k = {k}")
  plt.show()
