# %% [markdown]
# <a href="https://colab.research.google.com/github/kocurvik/edu/blob/master/PSO/notebooks/PSO_hw06_en.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework 6 - Fourier combination
#
# Implement the function `combine` which combines two images by using only using the first and third quadrant after the fourier transform with the second and fourth quadrant of another image and then transforms the combined image back into image domain. The function should also display the two original images and the combined image.

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt


def combine(img1, img2):
  ...

# %%
# !wget https://raw.githubusercontent.com/kocurvik/edu/master/PSO/images/building.jpg
# !wget https://raw.githubusercontent.com/kocurvik/edu/master/PSO/images/elk.png
# Out:
# --2023-11-14 16:27:26--  https://raw.githubusercontent.com/kocurvik/edu/master/PSO/images/building.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 57259 (56K) [image/jpeg]
# Saving to: ‘building.jpg’
#
# building.jpg        100%[===================>]  55.92K  --.-KB/s    in 0.009s
#
# 2023-11-14 16:27:27 (6.01 MB/s) - ‘building.jpg’ saved [57259/57259]
#
# --2023-11-14 16:27:27--  https://raw.githubusercontent.com/kocurvik/edu/master/PSO/images/elk.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
img1 = cv2.imread('building.jpg', cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread('elk.png', cv2.IMREAD_GRAYSCALE)

plt.figure(figsize=(10, 8))
combine(img1, img2)
