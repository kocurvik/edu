# %% [markdown]
# <a href="https://colab.research.google.com/github/kocurvik/edu/blob/master/PSO/notebooks/hw2025/PSO_hw03_en.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework Exercise 3 - Histogram Equalization
#
# Implement a function which takes a grayscale image on input and outputs a grayscale image with equalized histogram. Use the algorithm described on [wikipedia](https://en.wikipedia.org/wiki/Histogram_equalization).

# %%
import numpy as np

def equalize_img_histogram(image):
  # implement in pure numpy
  return equalized_image

# %%
import cv2
from matplotlib import pyplot as plt

# !wget https://raw.githubusercontent.com/kocurvik/edu/master/PSO/images/building.jpg
# !wget https://raw.githubusercontent.com/kocurvik/edu/master/PSO/images/landscape_dull.png

img_b = cv2.cvtColor(cv2.imread('building.jpg'), cv2.COLOR_BGR2GRAY)
img_l = cv2.cvtColor(cv2.imread('landscape_dull.png'), cv2.COLOR_BGR2GRAY)

def show(img, title=None):
  plt.imshow(img, cmap='gray', vmin=0, vmax=255)
  plt.axis('off')
  plt.title(title)
  plt.show()

show(img_b, 'Original')
show(equalize_img_histogram(img_b), 'Equalized')
show(img_l, 'Original')
show(equalize_img_histogram(img_l), 'Equalized')
# Out:
# --2023-10-17 15:16:22--  https://raw.githubusercontent.com/kocurvik/edu/master/PSO/images/building.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 57259 (56K) [image/jpeg]
# Saving to: ‘building.jpg’
#
# building.jpg        100%[===================>]  55.92K  --.-KB/s    in 0.04s
#
# 2023-10-17 15:16:23 (1.36 MB/s) - ‘building.jpg’ saved [57259/57259]
#
# --2023-10-17 15:16:23--  https://raw.githubusercontent.com/kocurvik/edu/master/PSO/images/landscape_dull.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# ...
