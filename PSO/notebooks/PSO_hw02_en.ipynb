# %% [markdown]
# <a href="https://colab.research.google.com/github/kocurvik/edu/blob/master/PSO/notebooks/PSO_hw02_en.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework Exercise 2 - ASCII Art
#
# Your task in this exercise to write code that takes an image and converts it 200 characters wide ASCII art using the characters [' ', '.', '*', ':', 'o', 'd', 'H', '#']. The height of the ASCII art should be calculated so that the visual aspect ratio of the resulting image remains the same.

# %%
# !wget https://raw.githubusercontent.com/kocurvik/edu/master/PSO/images/elk.png
# Out:
# --2023-10-03 15:33:10--  https://raw.githubusercontent.com/kocurvik/edu/master/PSO/images/elk.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2017326 (1.9M) [image/png]
# Saving to: ‘elk.png’
#
# elk.png             100%[===================>]   1.92M  --.-KB/s    in 0.03s
#
# 2023-10-03 15:33:10 (72.7 MB/s) - ‘elk.png’ saved [2017326/2017326]

# %%
...
# Out:
# ododo:::.ooooHoododoooooooooooooooooooodooodooooodddddoooooooddooooooo:o:oooooooo:o:ooooo:oo:o::o:::o:ooo::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::doo:::**::::::::*::::::::::
# oooddd*o*.oodooooooooooooooooooooooooddodoodddoddoddoooooooooooooo:o:o:oooooooo::ooooo::ooooo::o::::ooo:::::::::::::::::::::::::::::::::::::::::::::::::::::::*:::::::**::::o:::o::o::::::::::::::::::::
# odo:*::::d*do:*.oooooooooooooooooooooooodddoooooodooooooooooooooo:oooooooooo:::o:::o::o:ooooo::::o:o:o:o:oo:::::::::::::::::::::::::::::::::::::::::::::::*:::::::**:*::*:::#o*::*::::::*:::::::::::*:*:
# o:ood::*.oo.:o:o.ooooooooooooooooooddoodooooooddoooooooooooooooooooooooooo::::o:::::::o::o::oo::oooo:::o::::::::::::::::::::::::::::::oo:o:::::::::::::::::::*:::::::**:***:H**:*#:*:*:::::*::::::::::::
# ...
