# %% [markdown]
# <a href="https://colab.research.google.com/github/kocurvik/edu/blob/master/PNSPV/notebooky/keras_2020/cv05_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cvičenie 5
#
# Na dnešnom cvičení sa budeme hrať s jedným umelým prípadom. Budeme pracovať s šedotónovými obrázkami do ktorých pridáme vlnivý šum. Ten pridáme pomocou modifikácie obrazu vo Fourierovom spektre. To nám zabezpečí funkcia. Aby sme to upočítali na cvičení, tak budeme pridávať len horizontálny šum. S kódom sa môžete pohrať a skúsiť spojazdniť detekciu aj šikmého šumu.
#
# Všetko budeme testovať na datasete, ktorý je podmnožinou datasetu ImageNet v zmenšenej forme na $91 \times 91$ a obrázky sú šedotónové.
#
# V rámci tohto cvičenie si vytvoríme generátor dát, vlastnú cenovú funkciu a metriku na sledovanie, vlastnú vrstvu siete.
#
# ## Disclaimer
#
# Aby sme si demonštrovali použitie stridu, tak budeme používať konvolučné siete, ktorých architektúra je pre nášu úlohu zbytočne zložitá a nedosahuje ani až také dobré výsledky. Pre tento jednoduchý problém by stačila aj jednoduchá plne prepojená sieť. Z dnešného cvičenia si preto neberte to, ako tvoriť architektúru skôr ako implementovať veci z úloh.

# %%
import keras
import cv2
import numpy as np
import matplotlib.pyplot as plt

from keras.layers import Dense, Conv2D, Flatten, Input, GlobalAveragePooling2D
from keras.models import Model

import os

# %% [markdown]
# Najprv si stiahneme dataset a extrahujeme si ho. V datasete sú tri zložky train, val a mini_train. Mini_train máme na predbežné testovanie tréningu ako sme si ukazovali na druhom cvičení.

# %%
# !wget http://sccg.sk/~kocur/downloads/dewave_dataset.zip
# Out:
# --2020-11-03 14:18:28--  http://sccg.sk/~kocur/downloads/dewave_dataset.zip
# Resolving sccg.sk (sccg.sk)... 158.195.85.131
# Connecting to sccg.sk (sccg.sk)|158.195.85.131|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 106631937 (102M) [application/zip]
# Saving to: ‘dewave_dataset.zip’
#
# dewave_dataset.zip  100%[===================>] 101.69M  1.58MB/s    in 81s
#
# 2020-11-03 14:19:50 (1.25 MB/s) - ‘dewave_dataset.zip’ saved [106631937/106631937]

# %%
# !unzip dewave_dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: train/14441.jpg
#  extracting: train/14442.jpg
#  extracting: train/14443.jpg
#  extracting: train/14444.jpg
#  extracting: train/14445.jpg
#  extracting: train/14446.jpg
#  extracting: train/14447.jpg
#  extracting: train/14448.jpg
#  extracting: train/14449.jpg
#  extracting: train/14450.jpg
#  extracting: train/14451.jpg
#  extracting: train/14452.jpg
#  extracting: train/14453.jpg
#   inflating: train/14454.jpg
#  extracting: train/14455.jpg
#  extracting: train/14456.jpg
#  extracting: train/14457.jpg
#  extracting: train/14458.jpg
#  extracting: train/14459.jpg
#  extracting: train/14460.jpg
#   inflating: train/14461.jpg
#  extracting: train/14462.jpg
#   inflating: train/14463.jpg
#  extracting: train/14464.jpg
#   inflating: train/14465.jpg
#  extracting: train/14466.jpg
#  extracting: train/14467.jpg
#  extracting: train/14468.jpg
#  extracting: train/14469.jpg
#  extracting: train/14470.jpg
#  extracting: train/14471.jpg
#   inflating: train/14472.jpg
#  extracting: train/14473.jpg
#  extracting: train/14474.jpg
#  extracting: train/14475.jpg
#  extracting: train/14476.jpg
#  extracting: train/14477.jpg
#  extracting: train/14478.jpg
#  extracting: train/14479.jpg
#  extracting: train/14480.jpg
#   inflating: train/14481.jpg
#   inflating: train/14482.jpg
#   inflating: train/14483.jpg
#  extracting: train/14484.jpg
#  extracting: train/14485.jpg
#  extracting: train/14486.jpg
#  extracting: train/14487.jpg
#  extracting: train/14488.jpg
#   inflating: train/14489.jpg
#   inflating: train/14490.jpg
#  extracting: train/14491.jpg
#  extracting: train/14492.jpg
#  extracting: train/14493.jpg
#  extracting: train/14494.jpg
#   inflating: train/14495.jpg
#   inflating: train/14496.jpg
#  extracting: train/14497.jpg
#   inflating: train/14498.jpg
#  extracting: train/14499.jpg
#  extracting: train/14500.jpg
#   inflating: train/14501.jpg
#   inflating: train/14502.jpg
#  extracting: train/14503.jpg
#  extracting: train/14504.jpg
#   inflating: train/14505.jpg
#  extracting: train/14506.jpg
#   inflating: train/14507.jpg
#  extracting: train/14508.jpg
#  extracting: train/14509.jpg
#   inflating: train/14510.jpg
#  extracting: train/14511.jpg
#  extracting: train/14512.jpg
#  extracting: train/14513.jpg
#  extracting: train/14514.jpg
#  extracting: train/14515.jpg
#  extracting: train/14516.jpg
#  extracting: train/14517.jpg
#  extracting: train/14518.jpg
#  extracting: train/14519.jpg
#  extracting: train/14520.jpg
#  extracting: train/14521.jpg
#  extracting: train/14522.jpg
#  extracting: train/14523.jpg
#  extracting: train/14524.jpg
#  extracting: train/14525.jpg
#  extracting: train/14526.jpg
#  extracting: train/14527.jpg
#  extracting: train/14528.jpg
#  extracting: train/14529.jpg
#  extracting: train/14530.jpg
#   inflating: train/14531.jpg
#  extracting: train/14532.jpg
#  extracting: train/14533.jpg
#  extracting: train/14534.jpg
#  extracting: train/14535.jpg
#  extracting: train/14536.jpg
#  extracting: train/14537.jpg
#  extracting: train/14538.jpg
#   inflating: train/14539.jpg
#  extracting: train/14540.jpg
#   inflating: train/14541.jpg
#  extracting: train/14542.jpg
#  extracting: train/14543.jpg
#  extracting: train/14544.jpg
#  extracting: train/14545.jpg
#   inflating: train/14546.jpg
#  extracting: train/14547.jpg
#  extracting: train/14548.jpg
#   inflating: train/14549.jpg
#  extracting: train/14550.jpg
#  extracting: train/14551.jpg
#  extracting: train/14552.jpg
#  extracting: train/14553.jpg
#   inflating: train/14554.jpg
#   inflating: train/14555.jpg
#  extracting: train/14556.jpg
#  extracting: train/14557.jpg
#  extracting: train/14558.jpg
#  extracting: train/14559.jpg
#  extracting: train/14560.jpg
#  extracting: train/14561.jpg
#  extracting: train/14562.jpg
#  extracting: train/14563.jpg
#  extracting: train/14564.jpg
#  extracting: train/14565.jpg
#  extracting: train/14566.jpg
#  extracting: train/14567.jpg
#  extracting: train/14568.jpg
#  extracting: train/14569.jpg
#  extracting: train/14570.jpg
#  extracting: train/14571.jpg
#  extracting: train/14572.jpg
#  extracting: train/14573.jpg
#  extracting: train/14574.jpg
#  extracting: train/14575.jpg
#  extracting: train/14576.jpg
#  extracting: train/14577.jpg
#   inflating: train/14578.jpg
#   inflating: train/14579.jpg
#  extracting: train/14580.jpg
#  extracting: train/14581.jpg
#  extracting: train/14582.jpg
#  extracting: train/14583.jpg
#  extracting: train/14584.jpg
#  extracting: train/14585.jpg
#  extracting: train/14586.jpg
#   inflating: train/14587.jpg
#  extracting: train/14588.jpg
#  extracting: train/14589.jpg
#  extracting: train/14590.jpg
#  extracting: train/14591.jpg
#  extracting: train/14592.jpg
#  extracting: train/14593.jpg
#   inflating: train/14594.jpg
#   inflating: train/14595.jpg
#   inflating: train/14596.jpg
#  extracting: train/14597.jpg
#  extracting: train/14598.jpg
#  extracting: train/14599.jpg
#  extracting: train/14600.jpg
#  extracting: train/14601.jpg
#  extracting: train/14602.jpg
#  extracting: train/14603.jpg
#  extracting: train/14604.jpg
#  extracting: train/14605.jpg
#  extracting: train/14606.jpg
#  extracting: train/14607.jpg
#  extracting: train/14608.jpg
#  extracting: train/14609.jpg
#  extracting: train/14610.jpg
#  extracting: train/14611.jpg
#  extracting: train/14612.jpg
#  extracting: train/14613.jpg
#  extracting: train/14614.jpg
#  extracting: train/14615.jpg
#  extracting: train/14616.jpg
#  extracting: train/14617.jpg
#  extracting: train/14618.jpg
#  extracting: train/14619.jpg
#  extracting: train/14620.jpg
#  extracting: train/14621.jpg
#  extracting: train/14622.jpg
#  extracting: train/14623.jpg
#  extracting: train/14624.jpg
#  extracting: train/14625.jpg
#  extracting: train/14626.jpg
#  extracting: train/14627.jpg
#  extracting: train/14628.jpg
#  extracting: train/14629.jpg
#  extracting: train/14630.jpg
#  extracting: train/14631.jpg
#  extracting: train/14632.jpg
#  extracting: train/14633.jpg
#  extracting: train/14634.jpg
#  extracting: train/14635.jpg
#  extracting: train/14636.jpg
#   inflating: train/14637.jpg
#  extracting: train/14638.jpg
#  extracting: train/14639.jpg
#  extracting: train/14640.jpg
#  extracting: train/14641.jpg
#  extracting: train/14642.jpg
#  extracting: train/14643.jpg
#  extracting: train/14644.jpg
#  extracting: train/14645.jpg
#   inflating: train/14646.jpg
#  extracting: train/14647.jpg
#  extracting: train/14648.jpg
#  extracting: train/14649.jpg
#  extracting: train/14650.jpg
#   inflating: train/14651.jpg
#  extracting: train/14652.jpg
#  extracting: train/14653.jpg
#   inflating: train/14654.jpg
#  extracting: train/14655.jpg
#  extracting: train/14656.jpg
#  extracting: train/14657.jpg
#   inflating: train/14658.jpg
#   inflating: train/14659.jpg
#  extracting: train/14660.jpg
#   inflating: train/14661.jpg
#   inflating: train/14662.jpg
#   inflating: train/14663.jpg
#  extracting: train/14664.jpg
#  extracting: train/14665.jpg
#  extracting: train/14666.jpg
#  extracting: train/14667.jpg
#  extracting: train/14668.jpg
#  extracting: train/14669.jpg
#  extracting: train/14670.jpg
#   inflating: train/14671.jpg
#  extracting: train/14672.jpg
#   inflating: train/14673.jpg
#   inflating: train/14674.jpg
#   inflating: train/14675.jpg
#  extracting: train/14676.jpg
#   inflating: train/14677.jpg
#   inflating: train/14678.jpg
#   inflating: train/14679.jpg
#   inflating: train/14680.jpg
#  extracting: train/14681.jpg
#  extracting: train/14682.jpg
#  extracting: train/14683.jpg
#  extracting: train/14684.jpg
#  extracting: train/14685.jpg
#  extracting: train/14686.jpg
#  extracting: train/14687.jpg
#  extracting: train/14688.jpg
#  extracting: train/14689.jpg
#  extracting: train/14690.jpg
#  extracting: train/14691.jpg
#  extracting: train/14692.jpg
#  extracting: train/14693.jpg
#  extracting: train/14694.jpg
#  extracting: train/14695.jpg
#  extracting: train/14696.jpg
#  extracting: train/14697.jpg
#  extracting: train/14698.jpg
#   inflating: train/14699.jpg
#  extracting: train/14700.jpg
#  extracting: train/14701.jpg
#   inflating: train/14702.jpg
#  extracting: train/14703.jpg
#  extracting: train/14704.jpg
#  extracting: train/14705.jpg
#  extracting: train/14706.jpg
#  extracting: train/14707.jpg
#  extracting: train/14708.jpg
#  extracting: train/14709.jpg
#  extracting: train/14710.jpg
#  extracting: train/14711.jpg
#  extracting: train/14712.jpg
#  extracting: train/14713.jpg
#  extracting: train/14714.jpg
#  extracting: train/14715.jpg
#  extracting: train/14716.jpg
#  extracting: train/14717.jpg
#  extracting: train/14718.jpg
#  extracting: train/14719.jpg
#  extracting: train/14720.jpg
#  extracting: train/14721.jpg
#  extracting: train/14722.jpg
#  extracting: train/14723.jpg
#  extracting: train/14724.jpg
#  extracting: train/14725.jpg
#  extracting: train/14726.jpg
#  extracting: train/14727.jpg
#  extracting: train/14728.jpg
#  extracting: train/14729.jpg
#  extracting: train/14730.jpg
#   inflating: train/14731.jpg
#  extracting: train/14732.jpg
#  extracting: train/14733.jpg
#  extracting: train/14734.jpg
#   inflating: train/14735.jpg
#  extracting: train/14736.jpg
#  extracting: train/14737.jpg
#  extracting: train/14738.jpg
#  extracting: train/14739.jpg
#  extracting: train/14740.jpg
#  extracting: train/14741.jpg
#   inflating: train/14742.jpg
#  extracting: train/14743.jpg
#  extracting: train/14744.jpg
#  extracting: train/14745.jpg
#   inflating: train/14746.jpg
#   inflating: train/14747.jpg
#   inflating: train/14748.jpg
#  extracting: train/14749.jpg
#   inflating: train/14750.jpg
#  extracting: train/14751.jpg
#  extracting: train/14752.jpg
#   inflating: train/14753.jpg
#  extracting: train/14754.jpg
#  extracting: train/14755.jpg
#   inflating: train/14756.jpg
#  extracting: train/14757.jpg
#   inflating: train/14758.jpg
#  extracting: train/14759.jpg
#  extracting: train/14760.jpg
#   inflating: train/14761.jpg
#  extracting: train/14762.jpg
#  extracting: train/14763.jpg
#   inflating: train/14764.jpg
#   inflating: train/14765.jpg
#   inflating: train/14766.jpg
#  extracting: train/14767.jpg
#   inflating: train/14768.jpg
#  extracting: train/14769.jpg
#  extracting: train/14770.jpg
#  extracting: train/14771.jpg
#  extracting: train/14772.jpg
#   inflating: train/14773.jpg
#   inflating: train/14774.jpg
#   inflating: train/14775.jpg
#  extracting: train/14776.jpg
#  extracting: train/14777.jpg
#  extracting: train/14778.jpg
#  extracting: train/14779.jpg
#  extracting: train/14780.jpg
#  extracting: train/14781.jpg
#  extracting: train/14782.jpg
#  extracting: train/14783.jpg
#  extracting: train/14784.jpg
#  extracting: train/14785.jpg
#  extracting: train/14786.jpg
#  extracting: train/14787.jpg
#  extracting: train/14788.jpg
#  extracting: train/14789.jpg
#  extracting: train/14790.jpg
#  extracting: train/14791.jpg
#  extracting: train/14792.jpg
#  extracting: train/14793.jpg
#   inflating: train/14794.jpg
#  extracting: train/14795.jpg
#  extracting: train/14796.jpg
#  extracting: train/14797.jpg
#  extracting: train/14798.jpg
#  extracting: train/14799.jpg
#  extracting: train/14800.jpg
#  extracting: train/14801.jpg
#   inflating: train/14802.jpg
#  extracting: train/14803.jpg
#  extracting: train/14804.jpg
#  extracting: train/14805.jpg
#  extracting: train/14806.jpg
#  extracting: train/14807.jpg
#  extracting: train/14808.jpg
#  extracting: train/14809.jpg
#  extracting: train/14810.jpg
#   inflating: train/14811.jpg
#  extracting: train/14812.jpg
#   inflating: train/14813.jpg
#  extracting: train/14814.jpg
#  extracting: train/14815.jpg
#  extracting: train/14816.jpg
#  extracting: train/14817.jpg
#  extracting: train/14818.jpg
#  extracting: train/14819.jpg
#  extracting: train/14820.jpg
#  extracting: train/14821.jpg
#  extracting: train/14822.jpg
#  extracting: train/14823.jpg
#  extracting: train/14824.jpg
#  extracting: train/14825.jpg
#  extracting: train/14826.jpg
#  extracting: train/14827.jpg
#  extracting: train/14828.jpg
#   inflating: train/14829.jpg
#   inflating: train/14830.jpg
#  extracting: train/14831.jpg
#  extracting: train/14832.jpg
#  extracting: train/14833.jpg
#  extracting: train/14834.jpg
#  extracting: train/14835.jpg
#  extracting: train/14836.jpg
#  extracting: train/14837.jpg
#  extracting: train/14838.jpg
#  extracting: train/14839.jpg
#  extracting: train/14840.jpg
#  extracting: train/14841.jpg
#  extracting: train/14842.jpg
#   inflating: train/14843.jpg
#  extracting: train/14844.jpg
#  extracting: train/14845.jpg
#  extracting: train/14846.jpg
#   inflating: train/14847.jpg
#  extracting: train/14848.jpg
#  extracting: train/14849.jpg
#  extracting: train/14850.jpg
#  extracting: train/14851.jpg
#  extracting: train/14852.jpg
#   inflating: train/14853.jpg
#  extracting: train/14854.jpg
#  extracting: train/14855.jpg
#  extracting: train/14856.jpg
#  extracting: train/14857.jpg
#  extracting: train/14858.jpg
#  extracting: train/14859.jpg
#  extracting: train/14860.jpg
#   inflating: train/14861.jpg
#  extracting: train/14862.jpg
#  extracting: train/14863.jpg
#  extracting: train/14864.jpg
#  extracting: train/14865.jpg
#  extracting: train/14866.jpg
#  extracting: train/14867.jpg
#   inflating: train/14868.jpg
#  extracting: train/14869.jpg
#  extracting: train/14870.jpg
#  extracting: train/14871.jpg
#  extracting: train/14872.jpg
#  extracting: train/14873.jpg
#  extracting: train/14874.jpg
#  extracting: train/14875.jpg
#  extracting: train/14876.jpg
#  extracting: train/14877.jpg
#   inflating: train/14878.jpg
#  extracting: train/14879.jpg
#   inflating: train/14880.jpg
#  extracting: train/14881.jpg
#  extracting: train/14882.jpg
#  extracting: train/14883.jpg
#   inflating: train/14884.jpg
#  extracting: train/14885.jpg
#  extracting: train/14886.jpg
#  extracting: train/14887.jpg
#   inflating: train/14888.jpg
#  extracting: train/14889.jpg
#  extracting: train/14890.jpg
#  extracting: train/14891.jpg
#  extracting: train/14892.jpg
#  extracting: train/14893.jpg
#  extracting: train/14894.jpg
#  extracting: train/14895.jpg
#  extracting: train/14896.jpg
#  extracting: train/14897.jpg
#  extracting: train/14898.jpg
#  extracting: train/14899.jpg
#  extracting: train/14900.jpg
#  extracting: train/14901.jpg
#  extracting: train/14902.jpg
#  extracting: train/14903.jpg
#  extracting: train/14904.jpg
#  extracting: train/14905.jpg
#  extracting: train/14906.jpg
#  extracting: train/14907.jpg
#  extracting: train/14908.jpg
#  extracting: train/14909.jpg
#  extracting: train/14910.jpg
#  extracting: train/14911.jpg
#   inflating: train/14912.jpg
#   inflating: train/14913.jpg
#  extracting: train/14914.jpg
#   inflating: train/14915.jpg
#  extracting: train/14916.jpg
#  extracting: train/14917.jpg
#  extracting: train/14918.jpg
#  extracting: train/14919.jpg
#  extracting: train/14920.jpg
#  extracting: train/14921.jpg
#  extracting: train/14922.jpg
#  extracting: train/14923.jpg
#  extracting: train/14924.jpg
#  extracting: train/14925.jpg
#   inflating: train/14926.jpg
#   inflating: train/14927.jpg
#  extracting: train/14928.jpg
#  extracting: train/14929.jpg
#  extracting: train/14930.jpg
#  extracting: train/14931.jpg
#  extracting: train/14932.jpg
#  extracting: train/14933.jpg
#  extracting: train/14934.jpg
#  extracting: train/14935.jpg
#  extracting: train/14936.jpg
#  extracting: train/14937.jpg
#  extracting: train/14938.jpg
#  extracting: train/14939.jpg
#  extracting: train/14940.jpg
#  extracting: train/14941.jpg
#  extracting: train/14942.jpg
#  extracting: train/14943.jpg
#  extracting: train/14944.jpg
#  extracting: train/14945.jpg
#  extracting: train/14946.jpg
#  extracting: train/14947.jpg
#  extracting: train/14948.jpg
#  extracting: train/14949.jpg
#   inflating: train/14950.jpg
#   inflating: train/14951.jpg
#   inflating: train/14952.jpg
#  extracting: train/14953.jpg
#   inflating: train/14954.jpg
#  extracting: train/14955.jpg
#  extracting: train/14956.jpg
#  extracting: train/14957.jpg
#  extracting: train/14958.jpg
#   inflating: train/14959.jpg
#  extracting: train/14960.jpg
#  extracting: train/14961.jpg
#   inflating: train/14962.jpg
#  extracting: train/14963.jpg
#  extracting: train/14964.jpg
#  extracting: train/14965.jpg
#  extracting: train/14966.jpg
#  extracting: train/14967.jpg
#   inflating: train/14968.jpg
#  extracting: train/14969.jpg
#  extracting: train/14970.jpg
#  extracting: train/14971.jpg
#  extracting: train/14972.jpg
#  extracting: train/14973.jpg
#  extracting: train/14974.jpg
#  extracting: train/14975.jpg
#  extracting: train/14976.jpg
#  extracting: train/14977.jpg
#  extracting: train/14978.jpg
#  extracting: train/14979.jpg
#  extracting: train/14980.jpg
#  extracting: train/14981.jpg
#  extracting: train/14982.jpg
#  extracting: train/14983.jpg
#  extracting: train/14984.jpg
#   inflating: train/14985.jpg
#  extracting: train/14986.jpg
#  extracting: train/14987.jpg
#   inflating: train/14988.jpg
#   inflating: train/14989.jpg
#   inflating: train/14990.jpg
#  extracting: train/14991.jpg
#  extracting: train/14992.jpg
#  extracting: train/14993.jpg
#  extracting: train/14994.jpg
#  extracting: train/14995.jpg
#  extracting: train/14996.jpg
#  extracting: train/14997.jpg
#   inflating: train/14998.jpg
#   inflating: train/14999.jpg
#  extracting: train/15000.jpg
#  extracting: train/15001.jpg
#  extracting: train/15002.jpg
#  extracting: train/15003.jpg
#  extracting: train/15004.jpg
#  extracting: train/15005.jpg
#   inflating: train/15006.jpg
#  extracting: train/15007.jpg
#  extracting: train/15008.jpg
#  extracting: train/15009.jpg
#  extracting: train/15010.jpg
#  extracting: train/15011.jpg
#  extracting: train/15012.jpg
#  extracting: train/15013.jpg
#  extracting: train/15014.jpg
#   inflating: train/15015.jpg
#  extracting: train/15016.jpg
#  extracting: train/15017.jpg
#   inflating: train/15018.jpg
#  extracting: train/15019.jpg
#  extracting: train/15020.jpg
#  extracting: train/15021.jpg
#   inflating: train/15022.jpg
#  extracting: train/15023.jpg
#  extracting: train/15024.jpg
#  extracting: train/15025.jpg
#  extracting: train/15026.jpg
#  extracting: train/15027.jpg
#  extracting: train/15028.jpg
#  extracting: train/15029.jpg
#  extracting: train/15030.jpg
#   inflating: train/15031.jpg
#  extracting: train/15032.jpg
#  extracting: train/15033.jpg
#  extracting: train/15034.jpg
#   inflating: train/15035.jpg
#  extracting: train/15036.jpg
#  extracting: train/15037.jpg
#  extracting: train/15038.jpg
#  extracting: train/15039.jpg
#  extracting: train/15040.jpg
#  extracting: train/15041.jpg
#  extracting: train/15042.jpg
#  extracting: train/15043.jpg
#  extracting: train/15044.jpg
#  extracting: train/15045.jpg
#  extracting: train/15046.jpg
#  extracting: train/15047.jpg
#  extracting: train/15048.jpg
#  extracting: train/15049.jpg
#  extracting: train/15050.jpg
#  extracting: train/15051.jpg
#  extracting: train/15052.jpg
#  extracting: train/15053.jpg
#  extracting: train/15054.jpg
#  extracting: train/15055.jpg
#  extracting: train/15056.jpg
#  extracting: train/15057.jpg
#   inflating: train/15058.jpg
#  extracting: train/15059.jpg
#  extracting: train/15060.jpg
#  extracting: train/15061.jpg
#  extracting: train/15062.jpg
#  extracting: train/15063.jpg
#  extracting: train/15064.jpg
#  extracting: train/15065.jpg
#  extracting: train/15066.jpg
#  extracting: train/15067.jpg
#  extracting: train/15068.jpg
#  extracting: train/15069.jpg
#  extracting: train/15070.jpg
#  extracting: train/15071.jpg
#  extracting: train/15072.jpg
#  extracting: train/15073.jpg
#  extracting: train/15074.jpg
#  extracting: train/15075.jpg
#  extracting: train/15076.jpg
#   inflating: train/15077.jpg
#  extracting: train/15078.jpg
#  extracting: train/15079.jpg
#  extracting: train/15080.jpg
#  extracting: train/15081.jpg
#  extracting: train/15082.jpg
#  extracting: train/15083.jpg
#  extracting: train/15084.jpg
#  extracting: train/15085.jpg
#  extracting: train/15086.jpg
#  extracting: train/15087.jpg
#  extracting: train/15088.jpg
#  extracting: train/15089.jpg
#  extracting: train/15090.jpg
#  extracting: train/15091.jpg
#  extracting: train/15092.jpg
#  extracting: train/15093.jpg
#  extracting: train/15094.jpg
#  extracting: train/15095.jpg
#  extracting: train/15096.jpg
#  extracting: train/15097.jpg
#  extracting: train/15098.jpg
#  extracting: train/15099.jpg
#  extracting: train/15100.jpg
#  extracting: train/15101.jpg
#  extracting: train/15102.jpg
#  extracting: train/15103.jpg
#  extracting: train/15104.jpg
#  extracting: train/15105.jpg
#  extracting: train/15106.jpg
#  extracting: train/15107.jpg
#  extracting: train/15108.jpg
#  extracting: train/15109.jpg
#  extracting: train/15110.jpg
#  extracting: train/15111.jpg
#  extracting: train/15112.jpg
#  extracting: train/15113.jpg
#  extracting: train/15114.jpg
#  extracting: train/15115.jpg
#  extracting: train/15116.jpg
#  extracting: train/15117.jpg
#  extracting: train/15118.jpg
#  extracting: train/15119.jpg
#  extracting: train/15120.jpg
#  extracting: train/15121.jpg
#  extracting: train/15122.jpg
#  extracting: train/15123.jpg
#  extracting: train/15124.jpg
#  extracting: train/15125.jpg
#  extracting: train/15126.jpg
#  extracting: train/15127.jpg
#  extracting: train/15128.jpg
#  extracting: train/15129.jpg
#  extracting: train/15130.jpg
#  extracting: train/15131.jpg
#   inflating: train/15132.jpg
#   inflating: train/15133.jpg
#   inflating: train/15134.jpg
#  extracting: train/15135.jpg
#   inflating: train/15136.jpg
#  extracting: train/15137.jpg
#  extracting: train/15138.jpg
#  extracting: train/15139.jpg
#   inflating: train/15140.jpg
#   inflating: train/15141.jpg
#   inflating: train/15142.jpg
#  extracting: train/15143.jpg
#   inflating: train/15144.jpg
#   inflating: train/15145.jpg
#   inflating: train/15146.jpg
#  extracting: train/15147.jpg
#   inflating: train/15148.jpg
#   inflating: train/15149.jpg
#  extracting: train/15150.jpg
#   inflating: train/15151.jpg
#   inflating: train/15152.jpg
#   inflating: train/15153.jpg
#   inflating: train/15154.jpg
#   inflating: train/15155.jpg
#   inflating: train/15156.jpg
#   inflating: train/15157.jpg
#   inflating: train/15158.jpg
#   inflating: train/15159.jpg
#   inflating: train/15160.jpg
#  extracting: train/15161.jpg
#  extracting: train/15162.jpg
#   inflating: train/15163.jpg
#   inflating: train/15164.jpg
#   inflating: train/15165.jpg
#  extracting: train/15166.jpg
#   inflating: train/15167.jpg
#   inflating: train/15168.jpg
#   inflating: train/15169.jpg
#   inflating: train/15170.jpg
#  extracting: train/15171.jpg
#  extracting: train/15172.jpg
#  extracting: train/15173.jpg
#   inflating: train/15174.jpg
#  extracting: train/15175.jpg
#  extracting: train/15176.jpg
#   inflating: train/15177.jpg
#  extracting: train/15178.jpg
#  extracting: train/15179.jpg
#  extracting: train/15180.jpg
#  extracting: train/15181.jpg
#  extracting: train/15182.jpg
#   inflating: train/15183.jpg
#  extracting: train/15184.jpg
#   inflating: train/15185.jpg
#  extracting: train/15186.jpg
#  extracting: train/15187.jpg
#  extracting: train/15188.jpg
#   inflating: train/15189.jpg
#   inflating: train/15190.jpg
#  extracting: train/15191.jpg
#  extracting: train/15192.jpg
#   inflating: train/15193.jpg
#  extracting: train/15194.jpg
#  extracting: train/15195.jpg
#   inflating: train/15196.jpg
#   inflating: train/15197.jpg
#  extracting: train/15198.jpg
#  extracting: train/15199.jpg
#   inflating: train/15200.jpg
#  extracting: train/15201.jpg
#  extracting: train/15202.jpg
#  extracting: train/15203.jpg
#  extracting: train/15204.jpg
#  extracting: train/15205.jpg
#  extracting: train/15206.jpg
#  extracting: train/15207.jpg
#  extracting: train/15208.jpg
#  extracting: train/15209.jpg
#  extracting: train/15210.jpg
#  extracting: train/15211.jpg
#  extracting: train/15212.jpg
#  extracting: train/15213.jpg
#  extracting: train/15214.jpg
#  extracting: train/15215.jpg
#   inflating: train/15216.jpg
#  extracting: train/15217.jpg
#  extracting: train/15218.jpg
#   inflating: train/15219.jpg
#   inflating: train/15220.jpg
#  extracting: train/15221.jpg
#  extracting: train/15222.jpg
#  extracting: train/15223.jpg
#  extracting: train/15224.jpg
#  extracting: train/15225.jpg
#  extracting: train/15226.jpg
#  extracting: train/15227.jpg
#  extracting: train/15228.jpg
#  extracting: train/15229.jpg
#  extracting: train/15230.jpg
#   inflating: train/15231.jpg
#  extracting: train/15232.jpg
#   inflating: train/15233.jpg
#  extracting: train/15234.jpg
#  extracting: train/15235.jpg
#  extracting: train/15236.jpg
#  extracting: train/15237.jpg
#  extracting: train/15238.jpg
#  extracting: train/15239.jpg
#  extracting: train/15240.jpg
#   inflating: train/15241.jpg
#  extracting: train/15242.jpg
#  extracting: train/15243.jpg
#  extracting: train/15244.jpg
#   inflating: train/15245.jpg
#  extracting: train/15246.jpg
#  extracting: train/15247.jpg
#  extracting: train/15248.jpg
#  extracting: train/15249.jpg
#   inflating: train/15250.jpg
#  extracting: train/15251.jpg
#  extracting: train/15252.jpg
#  extracting: train/15253.jpg
#  extracting: train/15254.jpg
#  extracting: train/15255.jpg
#  extracting: train/15256.jpg
#  extracting: train/15257.jpg
#  extracting: train/15258.jpg
#  extracting: train/15259.jpg
#  extracting: train/15260.jpg
#  extracting: train/15261.jpg
#  extracting: train/15262.jpg
#  extracting: train/15263.jpg
#   inflating: train/15264.jpg
#  extracting: train/15265.jpg
#  extracting: train/15266.jpg
#  extracting: train/15267.jpg
#  extracting: train/15268.jpg
#  extracting: train/15269.jpg
#  extracting: train/15270.jpg
#  extracting: train/15271.jpg
#  extracting: train/15272.jpg
#  extracting: train/15273.jpg
#  extracting: train/15274.jpg
#   inflating: train/15275.jpg
#  extracting: train/15276.jpg
#  extracting: train/15277.jpg
#  extracting: train/15278.jpg
#  extracting: train/15279.jpg
#  extracting: train/15280.jpg
#  extracting: train/15281.jpg
#  extracting: train/15282.jpg
#  extracting: train/15283.jpg
#  extracting: train/15284.jpg
#  extracting: train/15285.jpg
#  extracting: train/15286.jpg
#  extracting: train/15287.jpg
#  extracting: train/15288.jpg
#  extracting: train/15289.jpg
#  extracting: train/15290.jpg
#  extracting: train/15291.jpg
#  extracting: train/15292.jpg
#  extracting: train/15293.jpg
#  extracting: train/15294.jpg
#  extracting: train/15295.jpg
#  extracting: train/15296.jpg
#  extracting: train/15297.jpg
#  extracting: train/15298.jpg
#  extracting: train/15299.jpg
#  extracting: train/15300.jpg
#  extracting: train/15301.jpg
#   inflating: train/15302.jpg
#  extracting: train/15303.jpg
#  extracting: train/15304.jpg
#  extracting: train/15305.jpg
#  extracting: train/15306.jpg
#  extracting: train/15307.jpg
#  extracting: train/15308.jpg
#  extracting: train/15309.jpg
#  extracting: train/15310.jpg
#  extracting: train/15311.jpg
#  extracting: train/15312.jpg
#  extracting: train/15313.jpg
#  extracting: train/15314.jpg
#  extracting: train/15315.jpg
#  extracting: train/15316.jpg
#   inflating: train/15317.jpg
#  extracting: train/15318.jpg
#   inflating: train/15319.jpg
#  extracting: train/15320.jpg
#  extracting: train/15321.jpg
#  extracting: train/15322.jpg
#  extracting: train/15323.jpg
#  extracting: train/15324.jpg
#  extracting: train/15325.jpg
#  extracting: train/15326.jpg
#  extracting: train/15327.jpg
#  extracting: train/15328.jpg
#  extracting: train/15329.jpg
#  extracting: train/15330.jpg
#   inflating: train/15331.jpg
#  extracting: train/15332.jpg
#  extracting: train/15333.jpg
#  extracting: train/15334.jpg
#  extracting: train/15335.jpg
#  extracting: train/15336.jpg
#  extracting: train/15337.jpg
#  extracting: train/15338.jpg
#  extracting: train/15339.jpg
#   inflating: train/15340.jpg
#   inflating: train/15341.jpg
#  extracting: train/15342.jpg
#  extracting: train/15343.jpg
#  extracting: train/15344.jpg
#  extracting: train/15345.jpg
#  extracting: train/15346.jpg
#  extracting: train/15347.jpg
#  extracting: train/15348.jpg
#  extracting: train/15349.jpg
#  extracting: train/15350.jpg
#  extracting: train/15351.jpg
#  extracting: train/15352.jpg
#  extracting: train/15353.jpg
#  extracting: train/15354.jpg
#  extracting: train/15355.jpg
#  extracting: train/15356.jpg
#   inflating: train/15357.jpg
#  extracting: train/15358.jpg
#  extracting: train/15359.jpg
#  extracting: train/15360.jpg
#  extracting: train/15361.jpg
#  extracting: train/15362.jpg
#  extracting: train/15363.jpg
#  extracting: train/15364.jpg
#  extracting: train/15365.jpg
#  extracting: train/15366.jpg
#  extracting: train/15367.jpg
#  extracting: train/15368.jpg
#  extracting: train/15369.jpg
#  extracting: train/15370.jpg
#  extracting: train/15371.jpg
#  extracting: train/15372.jpg
#  extracting: train/15373.jpg
#  extracting: train/15374.jpg
#  extracting: train/15375.jpg
#  extracting: train/15376.jpg
#  extracting: train/15377.jpg
#   inflating: train/15378.jpg
#   inflating: train/15379.jpg
#  extracting: train/15380.jpg
#  extracting: train/15381.jpg
#  extracting: train/15382.jpg
#  extracting: train/15383.jpg
#  extracting: train/15384.jpg
#  extracting: train/15385.jpg
#  extracting: train/15386.jpg
#  extracting: train/15387.jpg
#  extracting: train/15388.jpg
#  extracting: train/15389.jpg
#  extracting: train/15390.jpg
#  extracting: train/15391.jpg
#  extracting: train/15392.jpg
#   inflating: train/15393.jpg
#  extracting: train/15394.jpg
#  extracting: train/15395.jpg
#  extracting: train/15396.jpg
#  extracting: train/15397.jpg
#  extracting: train/15398.jpg
#  extracting: train/15399.jpg
#  extracting: train/15400.jpg
#  extracting: train/15401.jpg
#  extracting: train/15402.jpg
#  extracting: train/15403.jpg
#  extracting: train/15404.jpg
#  extracting: train/15405.jpg
#  extracting: train/15406.jpg
#  extracting: train/15407.jpg
#  extracting: train/15408.jpg
#  extracting: train/15409.jpg
#  extracting: train/15410.jpg
#  extracting: train/15411.jpg
#  extracting: train/15412.jpg
#  extracting: train/15413.jpg
#  extracting: train/15414.jpg
#   inflating: train/15415.jpg
#  extracting: train/15416.jpg
#   inflating: train/15417.jpg
#  extracting: train/15418.jpg
#  extracting: train/15419.jpg
#  extracting: train/15420.jpg
#   inflating: train/15421.jpg
#  extracting: train/15422.jpg
#   inflating: train/15423.jpg
#  extracting: train/15424.jpg
#  extracting: train/15425.jpg
#  extracting: train/15426.jpg
#  extracting: train/15427.jpg
#  extracting: train/15428.jpg
#  extracting: train/15429.jpg
#  extracting: train/15430.jpg
#  extracting: train/15431.jpg
#  extracting: train/15432.jpg
#  extracting: train/15433.jpg
#  extracting: train/15434.jpg
#  extracting: train/15435.jpg
#  extracting: train/15436.jpg
#  extracting: train/15437.jpg
#  extracting: train/15438.jpg
#  extracting: train/15439.jpg
#  extracting: train/15440.jpg
#  extracting: train/15441.jpg
#   inflating: train/15442.jpg
#  extracting: train/15443.jpg
#  extracting: train/15444.jpg
#  extracting: train/15445.jpg
#  extracting: train/15446.jpg
#  extracting: train/15447.jpg
#  extracting: train/15448.jpg
#  extracting: train/15449.jpg
#  extracting: train/15450.jpg
#  extracting: train/15451.jpg
#  extracting: train/15452.jpg
#  extracting: train/15453.jpg
#  extracting: train/15454.jpg
#  extracting: train/15455.jpg
#  extracting: train/15456.jpg
#  extracting: train/15457.jpg
#  extracting: train/15458.jpg
#  extracting: train/15459.jpg
#   inflating: train/15460.jpg
#  extracting: train/15461.jpg
#  extracting: train/15462.jpg
#  extracting: train/15463.jpg
#  extracting: train/15464.jpg
#  extracting: train/15465.jpg
#  extracting: train/15466.jpg
#  extracting: train/15467.jpg
#  extracting: train/15468.jpg
#  extracting: train/15469.jpg
#  extracting: train/15470.jpg
#   inflating: train/15471.jpg
#  extracting: train/15472.jpg
#  extracting: train/15473.jpg
#  extracting: train/15474.jpg
#  extracting: train/15475.jpg
#  extracting: train/15476.jpg
#  extracting: train/15477.jpg
#  extracting: train/15478.jpg
#  extracting: train/15479.jpg
#  extracting: train/15480.jpg
#  extracting: train/15481.jpg
#  extracting: train/15482.jpg
#  extracting: train/15483.jpg
#  extracting: train/15484.jpg
#  extracting: train/15485.jpg
#  extracting: train/15486.jpg
#  extracting: train/15487.jpg
#  extracting: train/15488.jpg
#  extracting: train/15489.jpg
#  extracting: train/15490.jpg
#  extracting: train/15491.jpg
#   inflating: train/15492.jpg
#  extracting: train/15493.jpg
#  extracting: train/15494.jpg
#  extracting: train/15495.jpg
#  extracting: train/15496.jpg
#  extracting: train/15497.jpg
#   inflating: train/15498.jpg
#  extracting: train/15499.jpg
#  extracting: train/15500.jpg
#  extracting: train/15501.jpg
#  extracting: train/15502.jpg
#  extracting: train/15503.jpg
#   inflating: train/15504.jpg
#  extracting: train/15505.jpg
#  extracting: train/15506.jpg
#  extracting: train/15507.jpg
#  extracting: train/15508.jpg
#  extracting: train/15509.jpg
#  extracting: train/15510.jpg
#  extracting: train/15511.jpg
#  extracting: train/15512.jpg
#  extracting: train/15513.jpg
#  extracting: train/15514.jpg
#  extracting: train/15515.jpg
#  extracting: train/15516.jpg
#  extracting: train/15517.jpg
#  extracting: train/15518.jpg
#  extracting: train/15519.jpg
#  extracting: train/15520.jpg
#  extracting: train/15521.jpg
#  extracting: train/15522.jpg
#  extracting: train/15523.jpg
#  extracting: train/15524.jpg
#  extracting: train/15525.jpg
#  extracting: train/15526.jpg
#  extracting: train/15527.jpg
#  extracting: train/15528.jpg
#  extracting: train/15529.jpg
#  extracting: train/15530.jpg
#  extracting: train/15531.jpg
#  extracting: train/15532.jpg
#  extracting: train/15533.jpg
#  extracting: train/15534.jpg
#  extracting: train/15535.jpg
#   inflating: train/15536.jpg
#  extracting: train/15537.jpg
#  extracting: train/15538.jpg
#  extracting: train/15539.jpg
#  extracting: train/15540.jpg
#  extracting: train/15541.jpg
#  extracting: train/15542.jpg
#  extracting: train/15543.jpg
#   inflating: train/15544.jpg
#  extracting: train/15545.jpg
#  extracting: train/15546.jpg
#  extracting: train/15547.jpg
#  extracting: train/15548.jpg
#  extracting: train/15549.jpg
#   inflating: train/15550.jpg
#  extracting: train/15551.jpg
#  extracting: train/15552.jpg
#  extracting: train/15553.jpg
#  extracting: train/15554.jpg
#  extracting: train/15555.jpg
#  extracting: train/15556.jpg
#  extracting: train/15557.jpg
#  extracting: train/15558.jpg
#  extracting: train/15559.jpg
#  extracting: train/15560.jpg
#   inflating: train/15561.jpg
#  extracting: train/15562.jpg
#  extracting: train/15563.jpg
#  extracting: train/15564.jpg
#  extracting: train/15565.jpg
#  extracting: train/15566.jpg
#  extracting: train/15567.jpg
#  extracting: train/15568.jpg
#   inflating: train/15569.jpg
#   inflating: train/15570.jpg
#  extracting: train/15571.jpg
#   inflating: train/15572.jpg
#  extracting: train/15573.jpg
#  extracting: train/15574.jpg
#   inflating: train/15575.jpg
#  extracting: train/15576.jpg
#  extracting: train/15577.jpg
#  extracting: train/15578.jpg
#  extracting: train/15579.jpg
#  extracting: train/15580.jpg
#  extracting: train/15581.jpg
#  extracting: train/15582.jpg
#  extracting: train/15583.jpg
#  extracting: train/15584.jpg
#   inflating: train/15585.jpg
#  extracting: train/15586.jpg
#   inflating: train/15587.jpg
#  extracting: train/15588.jpg
#  extracting: train/15589.jpg
#  extracting: train/15590.jpg
#  extracting: train/15591.jpg
#  extracting: train/15592.jpg
#  extracting: train/15593.jpg
#  extracting: train/15594.jpg
#  extracting: train/15595.jpg
#  extracting: train/15596.jpg
#  extracting: train/15597.jpg
#  extracting: train/15598.jpg
#  extracting: train/15599.jpg
#  extracting: train/15600.jpg
#  extracting: train/15601.jpg
#   inflating: train/15602.jpg
#  extracting: train/15603.jpg
#  extracting: train/15604.jpg
#  extracting: train/15605.jpg
#  extracting: train/15606.jpg
#   inflating: train/15607.jpg
#  extracting: train/15608.jpg
#  extracting: train/15609.jpg
#  extracting: train/15610.jpg
#  extracting: train/15611.jpg
#  extracting: train/15612.jpg
#  extracting: train/15613.jpg
#  extracting: train/15614.jpg
#  extracting: train/15615.jpg
#  extracting: train/15616.jpg
#   inflating: train/15617.jpg
#  extracting: train/15618.jpg
#  extracting: train/15619.jpg
#  extracting: train/15620.jpg
#  extracting: train/15621.jpg
#  extracting: train/15622.jpg
#   inflating: train/15623.jpg
#  extracting: train/15624.jpg
#  extracting: train/15625.jpg
#  extracting: train/15626.jpg
#   inflating: train/15627.jpg
#  extracting: train/15628.jpg
#  extracting: train/15629.jpg
#   inflating: train/15630.jpg
#  extracting: train/15631.jpg
#  extracting: train/15632.jpg
#  extracting: train/15633.jpg
#  extracting: train/15634.jpg
#  extracting: train/15635.jpg
#  extracting: train/15636.jpg
#  extracting: train/15637.jpg
#  extracting: train/15638.jpg
#  extracting: train/15639.jpg
#  extracting: train/15640.jpg
#  extracting: train/15641.jpg
#  extracting: train/15642.jpg
#  extracting: train/15643.jpg
#  extracting: train/15644.jpg
#   inflating: train/15645.jpg
#  extracting: train/15646.jpg
#  extracting: train/15647.jpg
#   inflating: train/15648.jpg
#   inflating: train/15649.jpg
#  extracting: train/15650.jpg
#  extracting: train/15651.jpg
#  extracting: train/15652.jpg
#   inflating: train/15653.jpg
#  extracting: train/15654.jpg
#  extracting: train/15655.jpg
#  extracting: train/15656.jpg
#  extracting: train/15657.jpg
#  extracting: train/15658.jpg
#  extracting: train/15659.jpg
#  extracting: train/15660.jpg
#  extracting: train/15661.jpg
#  extracting: train/15662.jpg
#  extracting: train/15663.jpg
#   inflating: train/15664.jpg
#  extracting: train/15665.jpg
#  extracting: train/15666.jpg
#   inflating: train/15667.jpg
#  extracting: train/15668.jpg
#  extracting: train/15669.jpg
#  extracting: train/15670.jpg
#  extracting: train/15671.jpg
#  extracting: train/15672.jpg
#  extracting: train/15673.jpg
#  extracting: train/15674.jpg
#   inflating: train/15675.jpg
#  extracting: train/15676.jpg
#  extracting: train/15677.jpg
#  extracting: train/15678.jpg
#  extracting: train/15679.jpg
#  extracting: train/15680.jpg
#  extracting: train/15681.jpg
#  extracting: train/15682.jpg
#  extracting: train/15683.jpg
#  extracting: train/15684.jpg
#  extracting: train/15685.jpg
#  extracting: train/15686.jpg
#  extracting: train/15687.jpg
#  extracting: train/15688.jpg
#  extracting: train/15689.jpg
#  extracting: train/15690.jpg
#  extracting: train/15691.jpg
#  extracting: train/15692.jpg
#  extracting: train/15693.jpg
#  extracting: train/15694.jpg
#  extracting: train/15695.jpg
#  extracting: train/15696.jpg
#  extracting: train/15697.jpg
#  extracting: train/15698.jpg
#  extracting: train/15699.jpg
#  extracting: train/15700.jpg
#  extracting: train/15701.jpg
# ...
#  extracting: val/02399.jpg
#  extracting: val/02400.jpg
#  extracting: val/02401.jpg
#  extracting: val/02402.jpg
#  extracting: val/02403.jpg
#  extracting: val/02404.jpg
#  extracting: val/02405.jpg
#  extracting: val/02406.jpg
#  extracting: val/02407.jpg
#  extracting: val/02408.jpg
#  extracting: val/02409.jpg
#  extracting: val/02410.jpg
#  extracting: val/02411.jpg
#  extracting: val/02412.jpg
#  extracting: val/02413.jpg
#  extracting: val/02414.jpg
#   inflating: val/02415.jpg
#  extracting: val/02416.jpg
#  extracting: val/02417.jpg
#   inflating: val/02418.jpg
#   inflating: val/02419.jpg
#  extracting: val/02420.jpg
#   inflating: val/02421.jpg
#   inflating: val/02422.jpg
#   inflating: val/02423.jpg
#  extracting: val/02424.jpg
#  extracting: val/02425.jpg
#  extracting: val/02426.jpg
#  extracting: val/02427.jpg
#  extracting: val/02428.jpg
#  extracting: val/02429.jpg
#  extracting: val/02430.jpg
#   inflating: val/02431.jpg
#  extracting: val/02432.jpg
#  extracting: val/02433.jpg
#   inflating: val/02434.jpg
#   inflating: val/02435.jpg
#  extracting: val/02436.jpg
#  extracting: val/02437.jpg
#  extracting: val/02438.jpg
#  extracting: val/02439.jpg
#  extracting: val/02440.jpg
#  extracting: val/02441.jpg
#  extracting: val/02442.jpg
#  extracting: val/02443.jpg
#  extracting: val/02444.jpg
#  extracting: val/02445.jpg
#   inflating: val/02446.jpg
#  extracting: val/02447.jpg
#  extracting: val/02448.jpg
#  extracting: val/02449.jpg
#  extracting: val/02450.jpg
#  extracting: val/02451.jpg
#  extracting: val/02452.jpg
#  extracting: val/02453.jpg
#  extracting: val/02454.jpg
#  extracting: val/02455.jpg
#  extracting: val/02456.jpg
#   inflating: val/02457.jpg
#  extracting: val/02458.jpg
#  extracting: val/02459.jpg
#   inflating: val/02460.jpg
#  extracting: val/02461.jpg
#  extracting: val/02462.jpg
#  extracting: val/02463.jpg
#  extracting: val/02464.jpg
#  extracting: val/02465.jpg
#  extracting: val/02466.jpg
#  extracting: val/02467.jpg
#  extracting: val/02468.jpg
#  extracting: val/02469.jpg
#  extracting: val/02470.jpg
#  extracting: val/02471.jpg
#  extracting: val/02472.jpg
#  extracting: val/02473.jpg
#  extracting: val/02474.jpg
#  extracting: val/02475.jpg
#   inflating: val/02476.jpg
#  extracting: val/02477.jpg
#  extracting: val/02478.jpg
#  extracting: val/02479.jpg
#   inflating: val/02480.jpg
#  extracting: val/02481.jpg
#   inflating: val/02482.jpg
#  extracting: val/02483.jpg
#  extracting: val/02484.jpg
#  extracting: val/02485.jpg
#   inflating: val/02486.jpg
#  extracting: val/02487.jpg
#  extracting: val/02488.jpg
#  extracting: val/02489.jpg
#   inflating: val/02490.jpg
#  extracting: val/02491.jpg
#  extracting: val/02492.jpg
#  extracting: val/02493.jpg
#   inflating: val/02494.jpg
#  extracting: val/02495.jpg
#  extracting: val/02496.jpg
#  extracting: val/02497.jpg
#  extracting: val/02498.jpg
#  extracting: val/02499.jpg
#  extracting: val/02500.jpg
#  extracting: val/02501.jpg
#  extracting: val/02502.jpg
#  extracting: val/02503.jpg
#  extracting: val/02504.jpg
#  extracting: val/02505.jpg
#  extracting: val/02506.jpg
#  extracting: val/02507.jpg
#  extracting: val/02508.jpg
#  extracting: val/02509.jpg
#  extracting: val/02510.jpg
#  extracting: val/02511.jpg
#   inflating: val/02512.jpg
#  extracting: val/02513.jpg
#  extracting: val/02514.jpg
#   inflating: val/02515.jpg
#  extracting: val/02516.jpg
#  extracting: val/02517.jpg
#  extracting: val/02518.jpg
#  extracting: val/02519.jpg
#   inflating: val/02520.jpg
#  extracting: val/02521.jpg
#  extracting: val/02522.jpg
#  extracting: val/02523.jpg
#  extracting: val/02524.jpg
#  extracting: val/02525.jpg
#   inflating: val/02526.jpg
#  extracting: val/02527.jpg
#  extracting: val/02528.jpg
#  extracting: val/02529.jpg
#  extracting: val/02530.jpg
#  extracting: val/02531.jpg
#  extracting: val/02532.jpg
#  extracting: val/02533.jpg
#  extracting: val/02534.jpg
#   inflating: val/02535.jpg
#  extracting: val/02536.jpg
#   inflating: val/02537.jpg
#  extracting: val/02538.jpg
#   inflating: val/02539.jpg
#   inflating: val/02540.jpg
#   inflating: val/02541.jpg
#   inflating: val/02542.jpg
#   inflating: val/02543.jpg
#  extracting: val/02544.jpg
#   inflating: val/02545.jpg
#   inflating: val/02546.jpg
#  extracting: val/02547.jpg
#  extracting: val/02548.jpg
#  extracting: val/02549.jpg
#  extracting: val/02550.jpg
#  extracting: val/02551.jpg
#  extracting: val/02552.jpg
#  extracting: val/02553.jpg
#  extracting: val/02554.jpg
#  extracting: val/02555.jpg
#  extracting: val/02556.jpg
#  extracting: val/02557.jpg
#  extracting: val/02558.jpg
#  extracting: val/02559.jpg
#   inflating: val/02560.jpg
#   inflating: val/02561.jpg
#  extracting: val/02562.jpg
#  extracting: val/02563.jpg
#  extracting: val/02564.jpg
#  extracting: val/02565.jpg
#  extracting: val/02566.jpg
#  extracting: val/02567.jpg
#  extracting: val/02568.jpg
#  extracting: val/02569.jpg
#  extracting: val/02570.jpg
#  extracting: val/02571.jpg
#  extracting: val/02572.jpg
#  extracting: val/02573.jpg
#  extracting: val/02574.jpg
#  extracting: val/02575.jpg
#  extracting: val/02576.jpg
#   inflating: val/02577.jpg
#   inflating: val/02578.jpg
#   inflating: val/02579.jpg
#  extracting: val/02580.jpg
#  extracting: val/02581.jpg
#  extracting: val/02582.jpg
#  extracting: val/02583.jpg
#   inflating: val/02584.jpg
#  extracting: val/02585.jpg
#  extracting: val/02586.jpg
#  extracting: val/02587.jpg
#  extracting: val/02588.jpg
#  extracting: val/02589.jpg
#   inflating: val/02590.jpg
#  extracting: val/02591.jpg
#  extracting: val/02592.jpg
#  extracting: val/02593.jpg
#  extracting: val/02594.jpg
#  extracting: val/02595.jpg
#  extracting: val/02596.jpg
#  extracting: val/02597.jpg
#  extracting: val/02598.jpg
#  extracting: val/02599.jpg
#  extracting: val/02600.jpg
#  extracting: val/02601.jpg
#  extracting: val/02602.jpg
#  extracting: val/02603.jpg
#  extracting: val/02604.jpg
#  extracting: val/02605.jpg
#  extracting: val/02606.jpg
#  extracting: val/02607.jpg
#  extracting: val/02608.jpg
#  extracting: val/02609.jpg
#  extracting: val/02610.jpg
#  extracting: val/02611.jpg
#  extracting: val/02612.jpg
#  extracting: val/02613.jpg
#  extracting: val/02614.jpg
#  extracting: val/02615.jpg
#  extracting: val/02616.jpg
#  extracting: val/02617.jpg
#   inflating: val/02618.jpg
#  extracting: val/02619.jpg
#  extracting: val/02620.jpg
#  extracting: val/02621.jpg
#  extracting: val/02622.jpg
#  extracting: val/02623.jpg
#  extracting: val/02624.jpg
#  extracting: val/02625.jpg
#   inflating: val/02626.jpg
#  extracting: val/02627.jpg
#  extracting: val/02628.jpg
#  extracting: val/02629.jpg
#  extracting: val/02630.jpg
#  extracting: val/02631.jpg
#  extracting: val/02632.jpg
#  extracting: val/02633.jpg
#  extracting: val/02634.jpg
#  extracting: val/02635.jpg
#  extracting: val/02636.jpg
#   inflating: val/02637.jpg
#  extracting: val/02638.jpg
#  extracting: val/02639.jpg
#  extracting: val/02640.jpg
#  extracting: val/02641.jpg
#  extracting: val/02642.jpg
#  extracting: val/02643.jpg
#  extracting: val/02644.jpg
#  extracting: val/02645.jpg
#   inflating: val/02646.jpg
#  extracting: val/02647.jpg
#  extracting: val/02648.jpg
#  extracting: val/02649.jpg
#  extracting: val/02650.jpg
#  extracting: val/02651.jpg
#  extracting: val/02652.jpg
#  extracting: val/02653.jpg
#   inflating: val/02654.jpg
#  extracting: val/02655.jpg
#  extracting: val/02656.jpg
#   inflating: val/02657.jpg
#  extracting: val/02658.jpg
#  extracting: val/02659.jpg
#   inflating: val/02660.jpg
#  extracting: val/02661.jpg
#  extracting: val/02662.jpg
#  extracting: val/02663.jpg
#  extracting: val/02664.jpg
#  extracting: val/02665.jpg
#  extracting: val/02666.jpg
#   inflating: val/02667.jpg
#  extracting: val/02668.jpg
#  extracting: val/02669.jpg
#   inflating: val/02670.jpg
#   inflating: val/02671.jpg
#  extracting: val/02672.jpg
#  extracting: val/02673.jpg
#  extracting: val/02674.jpg
#   inflating: val/02675.jpg
#   inflating: val/02676.jpg
#  extracting: val/02677.jpg
#  extracting: val/02678.jpg
#  extracting: val/02679.jpg
#   inflating: val/02680.jpg
#   inflating: val/02681.jpg
#  extracting: val/02682.jpg
#  extracting: val/02683.jpg
#  extracting: val/02684.jpg
#   inflating: val/02685.jpg
#  extracting: val/02686.jpg
#  extracting: val/02687.jpg
#  extracting: val/02688.jpg
#  extracting: val/02689.jpg
#  extracting: val/02690.jpg
#  extracting: val/02691.jpg
#   inflating: val/02692.jpg
#  extracting: val/02693.jpg
#  extracting: val/02694.jpg
#  extracting: val/02695.jpg
#  extracting: val/02696.jpg
#  extracting: val/02697.jpg
#  extracting: val/02698.jpg
#  extracting: val/02699.jpg
#  extracting: val/02700.jpg
#  extracting: val/02701.jpg
#   inflating: val/02702.jpg
#  extracting: val/02703.jpg
#  extracting: val/02704.jpg
#  extracting: val/02705.jpg
#  extracting: val/02706.jpg
#  extracting: val/02707.jpg
#  extracting: val/02708.jpg
#  extracting: val/02709.jpg
#  extracting: val/02710.jpg
#  extracting: val/02711.jpg
#  extracting: val/02712.jpg
#  extracting: val/02713.jpg
#  extracting: val/02714.jpg
#  extracting: val/02715.jpg
#  extracting: val/02716.jpg
#  extracting: val/02717.jpg
#  extracting: val/02718.jpg
#   inflating: val/02719.jpg
#  extracting: val/02720.jpg
#  extracting: val/02721.jpg
#  extracting: val/02722.jpg
#  extracting: val/02723.jpg
#  extracting: val/02724.jpg
#  extracting: val/02725.jpg
#  extracting: val/02726.jpg
#  extracting: val/02727.jpg
#  extracting: val/02728.jpg
#  extracting: val/02729.jpg
#  extracting: val/02730.jpg
#   inflating: val/02731.jpg
#  extracting: val/02732.jpg
#  extracting: val/02733.jpg
#   inflating: val/02734.jpg
#  extracting: val/02735.jpg
#  extracting: val/02736.jpg
#  extracting: val/02737.jpg
#  extracting: val/02738.jpg
#  extracting: val/02739.jpg
#  extracting: val/02740.jpg
#  extracting: val/02741.jpg
#  extracting: val/02742.jpg
#  extracting: val/02743.jpg
#  extracting: val/02744.jpg
#  extracting: val/02745.jpg
#  extracting: val/02746.jpg
#  extracting: val/02747.jpg
#  extracting: val/02748.jpg
#  extracting: val/02749.jpg
#  extracting: val/02750.jpg
#  extracting: val/02751.jpg
#  extracting: val/02752.jpg
#  extracting: val/02753.jpg
#  extracting: val/02754.jpg
#  extracting: val/02755.jpg
#  extracting: val/02756.jpg
#  extracting: val/02757.jpg
#  extracting: val/02758.jpg
#  extracting: val/02759.jpg
#  extracting: val/02760.jpg
#  extracting: val/02761.jpg
#  extracting: val/02762.jpg
#  extracting: val/02763.jpg
#  extracting: val/02764.jpg
#  extracting: val/02765.jpg
#  extracting: val/02766.jpg
#  extracting: val/02767.jpg
#  extracting: val/02768.jpg
#  extracting: val/02769.jpg
#  extracting: val/02770.jpg
#   inflating: val/02771.jpg
#   inflating: val/02772.jpg
#  extracting: val/02773.jpg
#  extracting: val/02774.jpg
#  extracting: val/02775.jpg
#  extracting: val/02776.jpg
#  extracting: val/02777.jpg
#  extracting: val/02778.jpg
#  extracting: val/02779.jpg
#  extracting: val/02780.jpg
#  extracting: val/02781.jpg
#  extracting: val/02782.jpg
#  extracting: val/02783.jpg
#  extracting: val/02784.jpg
#  extracting: val/02785.jpg
#   inflating: val/02786.jpg
#  extracting: val/02787.jpg
#  extracting: val/02788.jpg
#  extracting: val/02789.jpg
#  extracting: val/02790.jpg
#  extracting: val/02791.jpg
#  extracting: val/02792.jpg
#   inflating: val/02793.jpg
#  extracting: val/02794.jpg
#  extracting: val/02795.jpg
#  extracting: val/02796.jpg
#  extracting: val/02797.jpg
#  extracting: val/02798.jpg
#  extracting: val/02799.jpg
#  extracting: val/02800.jpg
#   inflating: val/02801.jpg
#  extracting: val/02802.jpg
#   inflating: val/02803.jpg
#   inflating: val/02804.jpg
#  extracting: val/02805.jpg
#   inflating: val/02806.jpg
#  extracting: val/02807.jpg
#  extracting: val/02808.jpg
#  extracting: val/02809.jpg
#  extracting: val/02810.jpg
#   inflating: val/02811.jpg
#  extracting: val/02812.jpg
#  extracting: val/02813.jpg
#   inflating: val/02814.jpg
#  extracting: val/02815.jpg
#  extracting: val/02816.jpg
#  extracting: val/02817.jpg
#  extracting: val/02818.jpg
#  extracting: val/02819.jpg

# %% [markdown]
# Funkcia predpokladá obrázky v tvare $91 \times 91$.

# %%
def add_regular_noise(img, row, col, plot=False):
    # cols in range 1..48
    # rows in range 1..95
    f = np.fft.fft2(img)
    fshift = np.fft.fftshift(f)

    if plot:
        magnitude_spectrum = 20 * np.log(np.abs(fshift))
        plt.subplot(221), plt.imshow(img, cmap='gray')
        plt.title('Input Image'), plt.xticks([]), plt.yticks([])
        plt.subplot(222), plt.imshow(magnitude_spectrum, cmap='gray')
        plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])

    val = np.abs(f[0,0])/5

    fshift[row, col] = val
    fshift[90-row, 90-col] = val
    img_modified = np.real(np.fft.ifft2(np.fft.ifftshift(fshift)))

    if plot:
        magnitude_spectrum = 20 * np.log(np.abs(fshift))
        plt.subplot(223), plt.imshow(np.real(img_modified), cmap='gray')
        plt.title('Output Image'), plt.xticks([]), plt.yticks([])
        plt.subplot(224), plt.imshow(magnitude_spectrum, cmap='gray')
        plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
        plt.show()

    return img_modified


def remove_regular_noise(img, row, col, plot=False):
      # cols in range 1..48
    # rows in range 1..95
    f = np.fft.fft2(img)
    fshift = np.fft.fftshift(f)

    if plot:
        magnitude_spectrum = 20 * np.log(np.abs(fshift))
        plt.subplot(221), plt.imshow(img, cmap='gray')
        plt.title('Input Image'), plt.xticks([]), plt.yticks([])
        plt.subplot(222), plt.imshow(magnitude_spectrum, cmap='gray')
        plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])

    fshift[row, col] = 0
    fshift[90-row, 90-col] = 0
    img_modified = np.real(np.fft.ifft2(np.fft.ifftshift(fshift)))

    if plot:
        magnitude_spectrum = 20 * np.log(np.abs(fshift))
        plt.subplot(223), plt.imshow(np.real(img_modified), cmap='gray')
        plt.title('Output Image'), plt.xticks([]), plt.yticks([])
        plt.subplot(224), plt.imshow(magnitude_spectrum, cmap='gray')
        plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
        plt.show()

    return img_modified

# %% [markdown]
# Otestujeme na obrázkoch

# %%
img = cv2.cvtColor(cv2.imread('train/00001.jpg'),cv2.COLOR_BGR2GRAY)
img_modified = add_regular_noise(img, 30, 15, plot=True)
img_repaired = remove_regular_noise(img_modified, 30, 15, plot=True)

img = cv2.cvtColor(cv2.imread('train/00090.jpg'),cv2.COLOR_BGR2GRAY)
img_modified = add_regular_noise(img, 5, 45, plot=True)

img = cv2.cvtColor(cv2.imread('train/00450.jpg'),cv2.COLOR_BGR2GRAY)
img_modified = add_regular_noise(img, 20, 45, plot=True)
img_repaired = remove_regular_noise(img_modified, 20, 45, plot=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:49: RuntimeWarning: divide by zero encountered in log

# %% [markdown]
# ## Generátor dát
#
# Budeme potrebovať generovať dáta pre náš model. Teda vždy do obrázku predtým než ho dáme do siete pridáme náhodné vlnenie.
#
# Na to vytvoríme triedu WaveGenerator, ktorá bude dediť s z keras.utils.Sequence
#
# Aby generátor fungoval, tak potrebujeme tri metódy `__init__`, `__get_item__` a `__len__`. Konštuktor nám pripraví dáta, get_item poskytuje dáta na trénovanie a len povie koľko krokov je jedna epocha.
#
# Je taktiež možné implementovať metódu on_epoch_end. Tá sa používa napríkla na premiešanie datasetu. My budeme vzorky vyberať úplne náhodne preto túto metódu nebudeme potrebovať.
#
# Vaša úloha bude doimplementovať metódu get_item. Zíde sa vám funkcia np.random.randint

# %%
class WaveGenerator(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, dir_path, batch_size=32, steps = 5000):
        'Initialization'
        self.batch_size = batch_size
        self.load_images(dir_path)
        self.steps = steps


    def load_images(self, dir_path):
        files = os.listdir(dir_path)
        images = []
        for file in files:
            file = file.strip()
            images.append(cv2.cvtColor(cv2.imread(os.path.join(dir_path, file)), cv2.COLOR_BGR2GRAY))
        self.images = np.array(images)/255

    def __len__(self):
        # return len(self.images)/self.batch_size
        return self.steps

    def __getitem__(self, index):
        rand_idxs = np.random.randint(0,self.images.shape[0],self.batch_size)
        X = np.empty([self.batch_size,91,91,1])
        y_row = np.empty([self.batch_size, 45])

        for b_idx, idx in enumerate(rand_idxs):
            rand_row = np.random.randint(0,45)
            X[b_idx, :, :, 0] = add_regular_noise(self.images[idx, :, :], rand_row, 45)
            y_row[b_idx, :] = keras.utils.to_categorical(rand_row, 45)

        return X, y_row

    def on_epoch_end(self):
        ...

# %% [markdown]
# ## Jednoduchá sieť
#
# Generátor môžeme použiť v jednoduchej sieti. Pomocou metódy fit_generator

# %%
input = Input(shape=(91,91,1))
conv_1_out = Conv2D(32,(7,7), strides=3, activation='relu')(input)
conv_2_out = Conv2D(32,(5,5), strides=2, activation='relu')(conv_1_out)
conv_3_out = Conv2D(32,(5,5), strides=2, activation='relu')(conv_2_out)
conv_4_out = Conv2D(32,(3,3), activation='relu')(conv_3_out)
conv_5_out = Conv2D(32,(3,3), activation='relu')(conv_4_out)

rows_1_out = Flatten()(conv_5_out)
rows_2_out = Dense(64, activation='relu')(rows_1_out)
rows_3_out = Dense(64, activation='relu')(rows_2_out)
rows_4_out = Dense(45, activation='softmax')(rows_3_out)

model = Model(inputs=input, outputs=rows_4_out)#,cols_4_out])
print(model.summary())

train_gen = WaveGenerator('train', steps=1000)
val_gen = WaveGenerator('val', steps = 200)

opt = keras.optimizers.Adam(lr=0.001)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit_generator(train_gen, validation_data=val_gen, epochs=1)
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 91, 91, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 29, 29, 32)        1600
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 32)        25632
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 5, 5, 32)          25632
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 3, 32)          9248
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 1, 1, 32)          9248
# _________________________________________________________________
# flatten (Flatten)            (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 64)                2112
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 45)                2925
# =================================================================
# Total params: 80,557
# Trainable params: 80,557
# Non-trainable params: 0
# _________________________________________________________________
# None
# WARNING:tensorflow:From <ipython-input-7-1e4de90df153>:22: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# 1000/1000 [==============================] - 36s 36ms/step - loss: 0.5239 - accuracy: 0.8616 - val_loss: 0.1509 - val_accuracy: 0.9634

# %% [markdown]
# Model môžeme otestovať

# %%
for i in range(8):
  img = cv2.imread('val/{:05d}.jpg'.format(i*100+1))
  img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
  img_modified = add_regular_noise(img, np.random.randint(0,45), 45)
  out = model.predict(img_modified[np.newaxis,:,:,np.newaxis])
  out_row = np.argmax(out[0])
  print(out_row)
  img_repaired = remove_regular_noise(img_modified, out_row, 45, plot=True)
# Out:
# 0
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:49: RuntimeWarning: divide by zero encountered in log
# 15
# 23
# 34
# 35
# 23
# 39
# 9

# %% [markdown]
# ## Regresia
# Klasifikácia funguje dobre. V našom prípade má aj celkom dobrý zmysel. Častokrát je však vhodné mať ako výstup modelu nejaké reálne číslo.
#
# Aby sme mohli trénovať sieť tak potrebujeme upraviť náš generátor. To urobíme obdobne ako pri predchádzajúcej úlohe.

# %%
class WaveRegGenerator(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, dir_path, batch_size=32, steps = 5000):
        'Initialization'
        self.batch_size = batch_size
        self.load_images(dir_path)
        self.steps = steps


    def load_images(self, dir_path):
        files = os.listdir(dir_path)
        images = []
        for file in files:
            file = file.strip()
            images.append(cv2.cvtColor(cv2.imread(os.path.join(dir_path, file)), cv2.COLOR_BGR2GRAY))
        self.images = np.array(images)/255

    def __len__(self):
        # return len(self.images)/self.batch_size
        return self.steps

    def __getitem__(self, index):
        rand_idxs = np.random.randint(0,self.images.shape[0],self.batch_size)
        X = np.empty([self.batch_size,91,91,1])
        y_row = np.empty([self.batch_size])

        for b_idx, idx in enumerate(rand_idxs):
            rand_row = np.random.randint(0,45)
            X[b_idx, :, :, 0] = add_regular_noise(self.images[idx, :, :], rand_row, 45)
            y_row[b_idx] = rand_row

        return X, y_row

    def on_epoch_end(self):
        ...

# %% [markdown]
# Model potom bude trocha odlišný na konci bdue len jedna vrstva bez aktivácie.

# %%
def build_model():
    input = Input(shape=(91,91,1))
    conv_1_out = Conv2D(32,(7,7), strides=3, activation='relu')(input)
    conv_2_out = Conv2D(32,(5,5), strides=2, activation='relu')(conv_1_out)
    conv_3_out = Conv2D(32,(5,5), strides=2, activation='relu')(conv_2_out)
    conv_4_out = Conv2D(32,(3,3), activation='relu')(conv_3_out)
    conv_5_out = Conv2D(32,(3,3), activation='relu')(conv_4_out)

    rows_1_out = Flatten()(conv_5_out)
    rows_2_out = Dense(64, activation='relu')(rows_1_out)
    rows_3_out = Dense(64, activation='relu')(rows_2_out)
    rows_4_out = Dense(1)(rows_3_out)

    return Model(inputs=input, outputs=rows_4_out)

# %% [markdown]
# Trénovať budeme zatiaľ pomocou mean squared error cenovej funkcie.

# %%
model = build_model()

print(model.summary())

train_gen = WaveRegGenerator('train', steps=1000)
val_gen = WaveRegGenerator('val', steps = 200)

opt = keras.optimizers.Adam(lr=0.001)
model.compile(optimizer=opt, loss='mse', metrics=['accuracy'])

history = model.fit_generator(train_gen, validation_data=val_gen, epochs=3)
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 91, 91, 1)]       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 29, 29, 32)        1600
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 13, 13, 32)        25632
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 5, 5, 32)          25632
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 3, 3, 32)          9248
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 1, 1, 32)          9248
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 77,697
# Trainable params: 77,697
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/3
# 1000/1000 [==============================] - 34s 34ms/step - loss: 49.4752 - accuracy: 0.0279 - val_loss: 8.4676 - val_accuracy: 0.0327
# Epoch 2/3
# 1000/1000 [==============================] - 34s 34ms/step - loss: 5.4672 - accuracy: 0.0366 - val_loss: 4.3097 - val_accuracy: 0.0422
# Epoch 3/3
# 1000/1000 [==============================] - 35s 35ms/step - loss: 3.4931 - accuracy: 0.0386 - val_loss: 2.1986 - val_accuracy: 0.0402

# %% [markdown]
# ## Porovnávacia metrika
#
# Pri trénovaní je síce super, že vieme ako sa vyvíja cena a presnosť (po zaokrúhlení), ale to nám nemusí stači. Chceli by sme si navrhnúť vlastnú metriku, ktorá nám viac napovie o vývoji trénovania. To sa nastaštie dá!
#
# Aby sme vyrobili metriku budeme potrebovať funkciu, ktorá na vstupe prijme výsledok siete a trénovacie y a vyhodí číslo. V rámci funkcie ale pracujem s objektmi, ktoré su typovo tenzory. Bežné operácie (+, -, * atď.) fungujú normálne. Na zložitejšie si musíme zavolať funkcie z backendu. V našom prípade to väčšinou znamená volať funkcie tzv. backendu. Keras dokáže bežať na rôznych backendoch preto budeme používať túto abstrakciu. Ak však viete, že budete používať iba tensorflow, tak je samozrejme možné používať priamo tensorflow funkcie.
#
# Teraz si vyrobíme funkciu, ktorá vráti presnosť našej metódy vzhľadom na nejakú toleranicu (napr. 3) teda chceme vedieť aký je podiel výstupov ktoré ležia nejakú vzdialenosť pri výstupe. Na to použijeme backendove metódy abs, less a mean.
#
# Pozn.: Vo funkcii môžeme využívať bežné floaty, alebo aj inak vygenerované vektory.

# %%
import keras.backend as K

# %%
def acc_within_range(y_pred, y_true):
    return K.mean(K.less(K.abs(y_pred - y_true),3))

# %%
model = build_model()

train_gen = WaveRegGenerator('train', steps=1000)
val_gen = WaveRegGenerator('val', steps = 200)

opt = keras.optimizers.Adam(lr=0.001)
model.compile(optimizer=opt, loss='mse', metrics=['accuracy', acc_within_range])

history = model.fit_generator(train_gen, validation_data=val_gen, epochs=2)
# Out:
# Epoch 1/2
# 1000/1000 [==============================] - 36s 36ms/step - loss: 44.4554 - accuracy: 0.0267 - acc_within_range: 0.5688 - val_loss: 15.4818 - val_accuracy: 0.0366 - val_acc_within_range: 0.5109
# Epoch 2/2
# 1000/1000 [==============================] - 36s 36ms/step - loss: 4.9906 - accuracy: 0.0406 - acc_within_range: 0.8710 - val_loss: 4.0582 - val_accuracy: 0.0437 - val_acc_within_range: 0.9048

# %% [markdown]
# ## Vlastná cenová funkcia
#
# MSE nemusí byť úplne najlepšia cenová funkcia aj keď sa bežne využíva. My si definujeme tzv. smooth L1 cenovú funkciu. Tá je podoná L1 norme chyby, až na to, že v okolí nuly je hladká. Definícia je nasledovná:
#
# $$ smooth_{L1}(x) = \begin{cases} \frac{1}{2} x^2 & \mbox{ak}~|x| \le 1 \\|x| - \frac{1}{2} & \mbox{inak} \end{cases}$$
#
# Postupovať budeme obdobne ako pri metrike. Teda vyrobíme funkciu, ktorá ma na vstupe y_pred a y_true. Z backendu sa vám zíde switch, abs a mean.

# %%
def smoothL1(y_true, y_pred):
    x   = K.abs(y_true - y_pred)
    x   = K.switch(x < 1, 0.5 * x ** 2, K.abs(x) - 0.5)
    return  K.mean(x)

# %%
model = build_model()

train_gen = WaveRegGenerator('train', steps=1000)
val_gen = WaveRegGenerator('val', steps = 200)

opt = keras.optimizers.Adam(lr=0.001)
model.compile(optimizer=opt, loss=smoothL1, metrics=['accuracy', acc_within_range])

history = model.fit_generator(train_gen, validation_data=val_gen, epochs=2)
# Out:
# Epoch 1/2
# 1000/1000 [==============================] - 36s 36ms/step - loss: 3.6086 - accuracy: 0.0331 - acc_within_range: 0.6217 - val_loss: 1.7857 - val_accuracy: 0.0419 - val_acc_within_range: 0.7250
# Epoch 2/2
# 1000/1000 [==============================] - 35s 35ms/step - loss: 0.9185 - accuracy: 0.0394 - acc_within_range: 0.9009 - val_loss: 0.5603 - val_accuracy: 0.0461 - val_acc_within_range: 0.9477

# %% [markdown]
# ## Vlastná vrstva
#
# Teraz si vyrobíme vlastnú vrstvu. Keďže v našom umelom prípade sa vždy snažíme v podstate identifikovať frekvenciu pridaných vĺn, tak by sme radi identifikovali tieto frekvencie. Na to použijeme konvolúciu s jadrom o rozmeroch $91 \times 1$. Týchto jadier budeme mať viacero a každé jadro bude predstavovať nejakú frekvenciu. Práve frekvencia a fázový posun budú naučiteľné parametre. Hodnoty jadra $w_0, w_1, ... w_90$ pre jednú frekvenciu $\omega$ a fázu $\phi$ budú:
#
# $$ w_k = \mbox{sin}\left( \frac{2\pi \cdot k}{90} \omega + \phi \right)$$.
#
# Pred aplikáciou ešte z obrazu odčítame 0.5 aby to dávalo zmysel. Toto jadro aplikujeme bez paddingu a tak nám akoby eliminuje jednu dimenziu (rád) tenzoru. Takto špecifické jadro samozrejme nebude možné použiť inde ako na začiatku našej siete.

# %% [markdown]
# Praktickú implementáciu budeme realizovať podľa [dokmentácie](https://keras.io/layers/writing-your-own-keras-layers/).
#
# Potrebujeme teda triedu, ktorá dedí od Layer. V konštruktore musím zavolať aj konštruktor predka. V konštruktore si zapamätáme koľko filtrov chceme použiť.
#
# Potom potrebujeme ešte tri metódy. Metóda build berie na vstup tvar vstupu do vrstvy (input_shape). V tejto metóde je nutné nainicializovať trénovateľné premenné. To pre nás bude vektor frekvencií a fáz. Tu sa oplatí ich nainicalizovať ako matice s jednou dimenziou 1. Dôležité je premenné správne nainicializovať. Na to použijeme rovnomernú distribúciu pomocou keras.initializers.RandomUniform. Frekvencie inicializujeme od -100 do 100 a fázu od $-\frac{\pi}{2}$ do $\frac{\pi}{2}$
#
# Ďalej potrebujeme metódu compute_output_shape, ktorá pre tvar vstupu vygeneruje tvar výstupu. Toto je pre nás jednoduché tvar bude rovnaký ako tvar vstupu, okrem výšky obrazu a počtu kanálov.
#
# Nakoniec naimplementujeme metódu call, ktorá sa používa pri trénovaní a inferencii. Ako jediný argument má vstupný tenzor. Vnútornú logiku musím skladať zo základných a backendových funkcií. V nej si najprv vygenerujeme zoznam hodnôt predstavujúci $\frac{2\pi \cdot k}{90}$ a ten potom prenásobíme s fázami, tak aby nám sedeli rozmery (využijeme maticové násobenie aj keď sú to vektory). Potom k nim pričítame fázy. Následne použijeme backendovú funkciu permute_dimensions, ktorou poprehadzujeme jadrá tak aby mali tvar: [filter_height, filter_width, in_channels, out_channels] tj. [91, 1, 1 $n_{filt}$]. Na toto sa nám zíde ešte metóda backendu expand dims aby sme mali čo prehadzovať.
#
# Keď máme kernel pripravený tak ho aplikujeme pomocou backendovej funkcie conv2d na vstupný tenzor ku ktorému ešte pričítame jednu polovicu.

# %%
class WaveLayer(keras.layers.Layer):

    def __init__(self, output_dim, **kwargs):
        self.output_dim = output_dim
        super(WaveLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        # Create a trainable weight variable for this layer.
        freq_init = keras.initializers.RandomUniform(minval=-100, maxval=100, seed=None)
        self.freqs = self.add_weight(name='frequencies', shape=(1,self.output_dim,), initializer=freq_init, trainable=True)
        phase_init = keras.initializers.RandomUniform(minval=-np.pi/2, maxval=np.pi/2, seed=None)
        self.phases = self.add_weight(name='phases', shape=(1,self.output_dim,), initializer=phase_init, trainable=True)

        super(WaveLayer, self).build(input_shape)  # Be sure to call this at the end

    def call(self, x):
        list_x = np.linspace(0,2*np.pi,91)[:, np.newaxis]
        list_phase = list_x * self.freqs + self.phases
        kernel = K.expand_dims(K.expand_dims(K.sin(list_phase), axis=0), axis=0)
        kernel = K.permute_dimensions(kernel, (2,0,1,3))

        return K.conv2d(x - 0.5, kernel, padding='valid')

    def compute_output_shape(self, input_shape):
        return (input_shape[0], 1, input_shape[2], self.output_dim)

# %% [markdown]
# Sieť teraz použijeme.

# %%
input = Input((91,91,1))
wave_out = WaveLayer(128)(input)
pool_out = GlobalAveragePooling2D()(wave_out)
dense_1_out = Dense(128, activation='relu')(pool_out)
dense_2_out = Dense(64, activation='relu')(dense_1_out)
dense_3_out = Dense(45, activation='softmax')(dense_2_out)

model = Model(inputs=input, outputs=dense_3_out)#,cols_4_out])
print(model.summary())

train_gen = WaveGenerator('train', steps=1000)
val_gen = WaveGenerator('val', steps = 200)

opt = keras.optimizers.Adam(lr=0.001)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

model.fit_generator(train_gen, validation_data=val_gen, epochs=3)
# Out:
# Model: "functional_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 91, 91, 1)]       0
# _________________________________________________________________
# wave_layer (WaveLayer)       (None, 1, 91, 128)        256
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_14 (Dense)             (None, 45)                2925
# =================================================================
# Total params: 27,949
# Trainable params: 27,949
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/3
# 1000/1000 [==============================] - 34s 34ms/step - loss: 0.2840 - accuracy: 0.9443 - val_loss: 0.0228 - val_accuracy: 0.9953
# Epoch 2/3
# 1000/1000 [==============================] - 34s 34ms/step - loss: 0.0203 - accuracy: 0.9952 - val_loss: 0.0145 - val_accuracy: 0.9955
# Epoch 3/3
# 1000/1000 [==============================] - 33s 33ms/step - loss: 0.0114 - accuracy: 0.9968 - val_loss: 0.0164 - val_accuracy: 0.9948
