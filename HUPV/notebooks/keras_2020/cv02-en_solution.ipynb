# %% [markdown]
# <a href="https://colab.research.google.com/github/kocurvik/edu/blob/master/PNSPV/notebooky/keras_2020/cv02-en_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **2nd Lab** - Linear algebra with NumPy, Fully connected neural network
#
# In this notebook we will go over basic linear algebra operations with NumPy and build our own neural network from scratch.

# %% [markdown]
# #Linear Algebra with NumPy
#
# To implement a fully connected neural network we will need to utlize matrix multiplication.

# %% [markdown]
# ## Matrix multiplication
# The most important matrix operation we will use is matrix multipllication. We will start with a definition:
#
# Let $\mathbf{A} \in \mathbb{R}^{m\times n}, \mathbf{B} \in \mathbb{R}^{n \times l}, \mathbf{C} \in \mathbb{R}^{m \times l} $ then $\mathbf{A}\mathbf{B} = \mathbf{C} \iff (\forall i \in \hat{m})(\forall j \in \hat{l})(c_{i,j} = \sum_{k=1}^{n} a_{i,k} \cdot b_{k,j})$
#
# It is important to remember that we the first subscript of a matrix element indicates the row and the second one indicates column.

# %% [markdown]
# ### Úloha 1 (On the whiteboard)
#
# Calculate $\mathbf{A}\mathbf{B}$, $\mathbf{B}\mathbf{C}$, $\mathbf{C}\mathbf{B}$
#
# $\mathbf{A} = \begin{bmatrix}
# 3 & 5 & -1 \\
# 2 & -4 & 2
# \end{bmatrix}$
#
# $\mathbf{B} = \begin{bmatrix}
# 5 & 2 & 1 \\
# -6 & 5 & 2 \\
# 3 & 4 & -1
# \end{bmatrix}$
#
# $\mathbf{C} = \begin{bmatrix}
# 4 & -4 & 3 \\
# -6 & -3 & 4 \\
# -1 & 1 & 0
# \end{bmatrix}$

# %% [markdown]
# In NumPy we can multiply matrices by using np.matmul(a, b), or by using the @ operator. We can also use np.dot. The difference between these two approaches is in broadcasting. Test this out for $\mathbf{BC}$ a $\mathbf{CB}$
#
# *Note:* Vectors can be though of as matrices with one of the dimensions being one. The singleton dimension determines whether it is a row or a column vector. Theoretically this affects the multiplication, but this might not be reflected in when working with NumPy. For example when using an array with len(np.shape) == 1 it is considered to be a row or a column vector based on what is better applicable in the current call.

# %%
import numpy as np
a = np.array([[3,5,-1],[2,-4,2]])
b = np.array([[5,2,1],[-6,5,2],[3,4,-1]])
print(np.matmul(a,b))
d = a @ b
print(d)
v = np.array([10,20,30])
print(v.shape)
u = np.array([5,25])
print(u.shape)
print(a @ v)
print(u @ a)
# Out:
# [[-18  27  14]
#  [ 40  -8  -8]]
# [[-18  27  14]
#  [ 40  -8  -8]]
# (3,)
# (2,)
# [100   0]
# [ 65 -75  45]

# %% [markdown]
# If we try to multiply a tensor of rank greater than 2 matmul will consider it as a list of matrices. If we need to perform something more fancy we can utilize np.einsum.

# %% [markdown]
# ## Scalar multiplication
#
# We can easily multiply a matrix by a scalar. This can be done with either np.multiply or with the * operator. If both of the operands are tensors then the multiplication will be carried out elementwise with broadcasting if applicable.

# %%
print(a * d)
print(5 * a)
# Out:
# [[-54 135 -14]
#  [ 80  32 -16]]
# [[ 15  25  -5]
#  [ 10 -20  10]]

# %% [markdown]
# ## Transposed matrices
#
# Definition: Let $\mathbf{A} \in \mathbb{R}^{m,n}$ then $\mathbf{A}^T \in \mathbb{R}^{n,m}$ is its transposed matrix $\iff (\forall i \in \hat{m})(\forall j \in \hat{n})(a_{i,j} = a^T_{j,i})$
#
# In NumPy we simply call the the method .T of any np.array. We can also use the function np.transpose. We can also use this to convert a row vector to a column vector and vice versa.

# %%
print(a.T)
print(np.transpose(a))

r = np.array([[100,10,1]])
print(r.shape)

c = np.array([[3],[7],[8]])
print(c.shape)

print(a @ c)
print(a @ r.T)
# Out:
# [[ 3  2]
#  [ 5 -4]
#  [-1  2]]
# [[ 3  2]
#  [ 5 -4]
#  [-1  2]]
# (1, 3)
# (3, 1)
# [[36]
#  [-6]]
# [[349]
#  [162]]

# %% [markdown]
# # Fully connected neural networks
# A neural network is a biologically inspired model used to perform various functions. Today we will use it as classifier.
#
# In general, we model the network as an orientede graph with valued edges nodes of which are the so-called neurons. Every neuron has its own activation, which is computed based on activations of neurons it is connected to. Any activation can then also affect further neurons. In the most general case we can describe the network activations as:
#
# $$a_p = f \left( \sum_{q \in p_{in}} w_{p,q} a_q + b_p \right) = f\left(z_p\right),$$
#
# where $a_p$ is the activation of a given node, $w_{p,q}$ is the weight between the node $q$ and $p$, $b_p$ is the bias of the node $p$, $f$ is the activation function, $z_p$ is a simplified expression we will use later. When using this broad definition it is possible for the neurons to be connected in a cyclic way which is undesirable. We also do not want the structure of the network to be too complicated. We will therefore introduce a fully connected neural network sometimes also denoted as a Multi-Layer-Perceptron. The added structure lies in the fact that every neuron has belongs to a layer and each neuron in a layer receives its inputs from all of the neurons in the previous layer.
#
# ![Fully connected neural network](https://raw.githubusercontent.com/kocurvik/edu/master/PNSPV/supplementary/ntb_images/NN1.jpg)
#
# Activations in the network can be then expressed as:
#
# $$a_j^l = f \left( \sum_{k} a_k^{l-1} w_{k,j}^l + b_j^l \right) = f \left(z_j^l \right),$$
#
# or in vector form:
#
# $$a^l = f \left( a^{l-1}w^l + b^l \right) =  f \left(z^l \right),$$
#
# where $a^l$ is the **row** vector of activations, $w^l$ is a weight matrix if $size(l-1) \times size(l)$, $a_l$ is a **column** vector of biases, $f$ is the scalar activation function, which is applied elementwise in the vector case, $z_l$ is also a row vector which is useful for simplifying expressions. The superscript indicates which layer the neuron belongs to.
#
# For a better understanding see the following images:
#
# ![Indexy aktivácie a prahu](https://raw.githubusercontent.com/kocurvik/edu/master/PNSPV/supplementary/ntb_images/activation_bias.jpg)
# ![Indexy váh](https://raw.githubusercontent.com/kocurvik/edu/master/PNSPV/supplementary/ntb_images/weight.jpg)
#
# *Note.:* The vectors could also be column vectors (this would result in the weight matrix being transposed), but this would create a few problems during implementation which arise due to broadcasting.

# %% [markdown]
# ### Activation functions
#
# We can use various activation functions. Today we will only use the sigmoid, but in future we will also use the other ones.
#
# 1. Sigmoid: $f(z) = \frac{1}{1 + e^{-z}}$
# 2. Tanh: $f(z) = tanh(z)$
# 3. ReLU: $f(z) = max(x,0)$
# 4. SoftPlus: $f(z) = ln(1 + e^z)$
# 5. LeakyReLU: $f(z) = max(x,ax), a \le 1$

# %% [markdown]
# ### Interpreting the last layer
#
# Our goal for this exercise is classification. Therefore we will interpret the last layer as numeric means of classification. If we intend to only classify our data into two classes we could only use one neuron with the sigmoid activation in the final layer. If the neuron outputs values less than 0.5 we will consider the input to be classified as the first class and if the output is greater than 0.5 we will consider the input to be classified as the second class.
#
# With more $n \gt 2$ classes we need more neurons. We can use the rule $k = {argmax}_{i \in \hat{n}}(a_i^L(x))$, where $L$ is the amount of layers in our netowork, $x$ is the input vecor $n$ is the amount of classes and $k$ is the class determined by the classifier.
#
# A bit more sophisticated approach is for example the softmax layer at the end instead of the standard activation. $P(k|x) = \frac{e^{z^L_k(x)}}{\sum_{i \in \hat n} e^{z^L_i(x)}}$, where $P(k|x)$ is the probability, that for the input $x$ the correct class is $k$.

# %% [markdown]
# ## Training
#
# Our model is so far nice, but we need to be able to find the activations which make it work. To do that we need to train the model using training data. We will use pairs $\left(x, y\right)$, where $x$ is the input and $y$ is the vector denoting the correct class. We will represent the output vector with **one-hot** encoding so that the vector $y$ will contain 1 in the $k$-th position and zeros everywhere else.

# %% [markdown]
# ### Loss function
#
# Training is similar to general optimization. We wanto to find the network paramters (in our cas $w$ and $b$) which will work best for our problem. To do this we will optimize for the value of so-called loss function. Ideally we construct the loss function in such a way in which a high loss value on some data indicates that the network is performing badly. We also want the loss function to be differentiable. Today we will use these functions for $N$ pairs of $\left(x^i, y^i\right)$:
#
# 1. MSE: $C = \frac{1}{N} \sum_i ||a^L(x^i) - y^i||_2^2$, where $||v||_2$ is the L2 norm of $v$.
# 2. Cross-Entropy:  $C = -\frac{1}{N} \sum_{i,j} y_j^i ln\left(a_j^L(x)\right) + \left(1-y_j^i\right) ln\left(1 - a_i^L(x) \right)$
# 3. CE + Softmax: $C = \frac{1}{N} ln(z_y^L(x))$, where $z_y^L(x)$ is the element o $z^L(x)$, for which the class is correct.

# %% [markdown]
# ### Gradient descent
#
# For optimization we will use a simple gradient descent rule with a step $\eta$ for parameter $p$ and loss function $C$.
#
# $$p := p - \eta \frac{\partial C}{\partial p}$$

# %% [markdown]
# ### SGD
#
# In each step of training we will use a random subset of the training data. In the following step we will use a different subset and so on. The subsets are called minibatches. This benefits the training since we introduce noise into the optimization process which can help us get out of local minima. Also the found minimum may have some desirable properties as opposed to standard optimization. This also reduces the necessary spatial requirements of our algorithm which is often the most limiting factor when dealing with neural networks.
#
# This approach is called **stochastic gradient descent (SGD)**.
#
# *Note:* By choosing a minibatch we are actually approximating the function $C$ for the whole training set. Statistically the error of this estimation decreases with  $\sim \frac{1}{\sqrt{M}}$, where $M$ is the size of the minibatch. Therefore it is not necessarily a good idea to use large minibatches even when the memory would be underutilized.

# %% [markdown]
# ### Calculating partial derivatives
#
# We will now derive how to calculate the partial derivatives for the parameters of our fully connected neural network.
#
# Let us first define a helper variable:
#
# $ d_i^l = \frac{\partial C}{\partial z_i^l}$
#
# Based on the choice of $C$ the $\odot$ operator means elementwise multiplication (* in NumPy).
#
# for MSE: $d_i^L = (a_i^L - y_i) \cdot f^{'} (z_i^L)$,
#
# for CE: $d_i^L = (a_i^L - y_i)$
#
# MSE (vectorized): $d_i^L = (a^L - y) \odot f^{'} (z^L)$
#
# CE (vectorized): $d^L = a^L - y$

# %% [markdown]
# Based on $d^{l+1}$ we can compute $d^l$. This approach is also called **backpropagation** since the gradient is calculated in the opposite order as when calculating the values in forward calculation of activations.
#
# $ d^l = \left(d^{l+1} \left( w^{l+1} \right)^T\right) \odot f^{'}(z^l)$
#
# Proof:
#
# $z_j^{l+1} = \sum_k \left( f \left( z^l_k\right) w_{kj}^{l+1} \right) + b_j^{l+1}$
#
# $\frac{\partial z_j^{l+1}}{\partial z_k^l} = f^{'} \left( z^l_k\right) w_{kj}^{l+1}$
#
# $d_k^l = \frac{\partial C}{\partial z_k^l} = \sum_j \frac{\partial C}{\partial z_j^{l+1}} \frac{\partial z_j^{l+1}}{\partial z_k^l} = \sum_j d_j^{l+1} f^{'} \left( z^l_k\right) w_{kj}^l$
#
# For the network parameters:
#
# $\frac{\partial C}{\partial b_j^l} = d_j^l$
#
# $\frac{\partial C}{\partial w_{kj}^l} = d_j^l a_k^{l-1}$
#
# Vectorized:
#
# $\frac{\partial C}{\partial b^l} = d^l$
#
# $\frac{\partial C}{\partial w_{}^l} = (a^{l-1})^T d^l $
#
# Proof:
#
# $z_j^l = \sum_k a_k^{l-1} w_{kj}^l + b_j^l$
#
# $\frac{\partial C}{\partial b_j^l} = \sum_k \frac{\partial C}{\partial z_k^l}\frac{\partial z_k^l}{\partial b_j^l} = \sum_k \delta_{kj} d_k^l = d_j^l$
#
# $\frac{\partial C}{\partial w_{kj}^l} = \sum_p \frac{\partial C}{\partial z_p^l}\frac{\partial z_p^l}{\partial w_{kj}^l} = \sum_p d_p^l \delta_{pj} a_k^{l-1} = d_j^l a_k^{l-1}$
#
# where $\delta_{jk} = 1$ if $j = k$, otherwise $ 0$.

# %% [markdown]
# ### Algorithm
#
# One step of our SGD algorithm is then:
# 1. We perform the forward computation - we save $z^l$ and $a^l$ values.
# 2. We calculate $d^L$ based on the loss function.
# 3. We backpropagate the error $d^l$ using the backpropagation rule.
# 4. We compute the partial derivatives from the previous step.
# 5. We repeat this for the whole minibatch and average the partial derivatives in order to update the parameter values according to the gradient descent rules.
#
# **Attention:** it is still important to initialize the parameters correctly. If we initialize all of them to the same values all of the partial derivatives will be the same and the network will thus be unable to create represantations which require more than one neuron per layer.

# %% [markdown]
# ## Implementation
#
# The following code contains the implementation of the base algorithm structure. Some of the code is missing and your job will be to implement the missing code segments. Instructions along with some test are presented below.

# %%
import numpy as np

def sigmoid(z):
    # returns the value after applying the sigmoid function
    return 1/(1+np.exp(-z))

def sigmoid_prime(z):
    # vráti the gradient of the sigmoid function
    return sigmoid(z)*(1-sigmoid(z))

def get_one_hot(targets, nb_classes):
    # returns the one-hot encoded vector in the sape it was loaded in
    res = np.eye(nb_classes)[np.array(targets).reshape(-1)]
    return res.reshape(list(targets.shape)+[nb_classes])

class Network():
    def __init__(self, arg):
        if isinstance(arg, str):
            # If our input is string we load a file
            self.load(arg)
        else:
            # Othewise we expect a list and use it to initialize the layers
            if len(arg) < 2:
                raise ValueError("Sizes must be at least 2!")

            self.w_list = []
            self.b_list = []
            # Here we initialize the weights
            for i in range(1, len(arg)):
                self.w_list.append(np.random.randn(arg[i - 1], arg[i]))
                self.b_list.append(0.1 * np.ones((arg[i])))

    def save(self, filename):
        # saves the network as a numpy file
        dict = np.array([self.w_list, self.b_list])
        np.save(filename, dict)

    def load(self, filename):
        # loads the network from a numpy file
        d = np.load(filename, allow_pickle=True)
        self.w_list = d[0].tolist()
        self.b_list = d[1].tolist()

    def fwd(self, a):
        # implement the forward pass
        for i in range(len(self.w_list)):
          a = sigmoid(a @ self.w_list[i] + self.b_list[i])
        return a

    def _step(self, X, y, batch_size, eta):
        # fill these lists with new values after one step
        new_w_list = [np.empty_like(w) for w in self.w_list]
        new_b_list = [np.empty_like(b) for b in self.b_list]

        # It is important to first perform the forward pass through the network
        # while remembering the values of a and z. It is possible that 
        # len(a_list) = len(z_list) + 1, since the first a is our input
        # This needs to be taken into consideration when idexing, but you can
        # also implement this in another way

        z_list = []
        a_list = [X]

        # Here we first fill the a_list and z_list

        for i in range(len(self.w_list)):
            z_list.append(np.matmul(a_list[i], self.w_list[i]))
            a_list.append(sigmoid(z_list[i]))


        # We calculate the error for a given step
        d_list = [[] for _ in z_list]
        err = np.sum((a_list[-1] - y)**2) / batch_size
        # d_list[-1] = (a_list[-1] - y)*sigmoid_prime(z_list[-1])

        # We calculate the d
        d_list[-1] = a_list[-1] - y

        # Here we do backprop
        new_w_list[-1] = self.w_list[-1] - (eta / batch_size) * np.matmul(a_list[-2].T, d_list[-1])
        new_b_list[-1] = self.b_list[-1] - (eta / batch_size) * np.sum(d_list[-1], axis= 0)
        for i in range(2, len(z_list)+1):
            d_list[-i] = (np.matmul(d_list[-i+1], self.w_list[-i+1].T))*sigmoid_prime(z_list[-i])
            new_w_list[-i] = self.w_list[-i] - (eta / batch_size) * np.matmul(a_list[-i-1].T, d_list[-i])
            new_b_list[-i] = self.b_list[-i] - (eta / batch_size) * np.sum(d_list[-i], axis=0)

        # Finally we update the parameters
        self.w_list = new_w_list
        self.b_list = new_b_list
        return err

    def eval(self, X, y):
        # This method runs the network on input X and calculates the output
        
        # Note: in a realistic case we would implement this to run on smaller
        # chunks of data, but since our model is small we can simply do it at once
        out = self.fwd(X)
        err = np.mean((out - y)**2)
        out_best = np.argmax(out, axis=-1)
        y_best = np.argmax(y, axis=-1)
        acc = np.sum(np.where(out_best == y_best, 1, 0))/y.shape[0]
        return acc, err

    def sgd(self, X, y, val_X, val_y, epochs, steps, batch_size, eta):
        for epoch in range(epochs):
            err_tot = 0
            for step in range(steps):
                batch_mask = np.random.choice(X.shape[0], batch_size)
                batch_X = X[batch_mask,:]
                batch_y = y[batch_mask,:]
                err = self._step(batch_X, batch_y, batch_size, eta)
                if step == 0:
                    err_tot = err
                else:
                    err_tot = 0.1 * err + 0.9 * err_tot
                print("At step: {}, running average training error: {}".format(step, err_tot))

            acc, err = self.eval(val_X, val_y)
            print("At Epoch {}, validation error: {}, validation accuracy {}".format(epoch, err, acc))

# %% [markdown]
# ### Exercise 2
#
# Implement the function sigmoid which applies the activation function on the input in an elementwise fashion.
#
#
# $$\sigma(z) = \frac{1}{1 + e^{-z}}$$
#
# Implemnt the derivative as well.
#
# $$\sigma (z)^{'} = \sigma (z)\left(1 - \sigma (z) \right)$$

# %%
assert(sigmoid(0) == 0.5)
assert(sigmoid(50) > 1.0-1e-10)
assert(sigmoid(-50) <= 2e-22)
assert((sigmoid(np.array([10, 20]))==np.array([sigmoid(10), sigmoid(20)])).all())
assert(sigmoid_prime(0) == 0.25)
assert(sigmoid_prime(-50) > 0 )
assert(sigmoid_prime(30) > 0 )

# %% [markdown]
# ### Exercise 3
#
# Load the MNIST data and feed some of the images to the network.

# %% [markdown]
# We will first load the dataset and display one of the images.

# %%
from sklearn.datasets import fetch_openml
mnist = fetch_openml('mnist_784')

X = mnist.data.astype('float32')/255
y = mnist.target.astype('int64')

# %%
import matplotlib.pyplot as plt

plt.imshow(np.reshape(X[0,],(28,28)), cmap='gray')
print(y[0])
# Out:
# 5

# %% [markdown]
# Implement the fwd method. The first test checks the dimension and the second one loads a pre-trained network and runs it on the MNIST dataset.

# %%
net = Network([28*28,30,20,10])
out = net.fwd(np.random.randn(32,784))
assert(out.shape == (32,10))
print("Passed")
# Out:
# Passed

# %%
# !wget https://github.com/kocurvik/edu/raw/master/PNNPPV/supplementary/test_net.npy
# Out:
# --2020-09-27 23:24:49--  https://github.com/kocurvik/edu/raw/master/PNNPPV/supplementary/test_net.npy
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/kocurvik/edu/master/PNNPPV/supplementary/test_net.npy [following]
# --2020-09-27 23:24:49--  https://raw.githubusercontent.com/kocurvik/edu/master/PNNPPV/supplementary/test_net.npy
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 304267 (297K) [application/octet-stream]
# Saving to: ‘test_net.npy.1’
#
# test_net.npy.1      100%[===================>] 297.14K  --.-KB/s    in 0.02s
#
# 2020-09-27 23:24:49 (13.5 MB/s) - ‘test_net.npy.1’ saved [304267/304267]

# %%
net = Network("test_net.npy")

R = net.fwd(X[0:3,:])

correct_list = []

for i in range(3):
  plt.imshow(np.reshape(X[i,:],(28,28)), cmap = 'gray')
  plt.show()
  print(R[i])
  print(np.argmax(R[i,:]))
  
print("Passed!")
# Out:
# [9.37229037e-04 2.66838142e-04 2.75842143e-05 9.41889344e-03
#  2.84101542e-08 3.63257568e-01 1.62064850e-07 8.06202488e-05
#  7.02270024e-04 6.57032697e-04]
# 5
# [9.94378188e-01 4.89519245e-07 3.28816149e-05 8.06781030e-05
#  6.55497717e-06 4.25255977e-05 1.82384777e-04 7.61480364e-04
#  2.06510936e-05 1.62541578e-03]
# 0
# [1.53046899e-05 1.98120978e-04 1.47761151e-03 6.18961861e-05
#  5.35841113e-01 1.93294785e-06 6.89669687e-06 3.71849632e-02
#  4.93958997e-05 2.59638688e-02]
# 4
# Passed!

# %% [markdown]
# ### Exercise 4
# Implement the _step method, which performs SGD for MSE or CE loss function. This method won't be tested directly, but we will try to apply it to training. These parameters should work well enough so that the network learns at least something.

# %%
train_X = X[:50000, :]
train_y = get_one_hot(y[:50000], 10)


val_X = X[50000:60000,:]
val_y = get_one_hot(y[50000:60000],10)
#
net = Network([28*28,30,20,10])
net.sgd(train_X, train_y, val_X, val_y, 10, 10000, 32, 0.01)
net.sgd(train_X, train_y, val_X, val_y, 10, 10000, 32, 0.03)
net.sgd(train_X, train_y, val_X, val_y, 10, 10000, 32, 0.001)
net.save("net.npy")
# Out:
# Streaming output truncated to the last 5000 lines.
# At step: 5002, running average training error: 0.08444784905143948
# At step: 5003, running average training error: 0.08085180784365127
# At step: 5004, running average training error: 0.08312664747637687
# At step: 5005, running average training error: 0.09199028640834053
# At step: 5006, running average training error: 0.0873039966382772
# At step: 5007, running average training error: 0.09511449718195486
# At step: 5008, running average training error: 0.089629446949449
# At step: 5009, running average training error: 0.08094300845318704
# At step: 5010, running average training error: 0.09502021501374742
# At step: 5011, running average training error: 0.09695821492057911
# At step: 5012, running average training error: 0.10615159323240847
# At step: 5013, running average training error: 0.10083519283942807
# At step: 5014, running average training error: 0.09851570195975337
# At step: 5015, running average training error: 0.1015980120452333
# At step: 5016, running average training error: 0.10475974505285048
# At step: 5017, running average training error: 0.103667049776377
# At step: 5018, running average training error: 0.09783145242638007
# At step: 5019, running average training error: 0.10373231963345635
# At step: 5020, running average training error: 0.09684058084053579
# At step: 5021, running average training error: 0.09123851037741972
# At step: 5022, running average training error: 0.08827624023384364
# At step: 5023, running average training error: 0.0821157412904038
# At step: 5024, running average training error: 0.08049151997907907
# At step: 5025, running average training error: 0.0855223092780531
# At step: 5026, running average training error: 0.08150369596534768
# At step: 5027, running average training error: 0.08297142741155307
# At step: 5028, running average training error: 0.09023796031404031
# At step: 5029, running average training error: 0.0910232940375625
# At step: 5030, running average training error: 0.09303270806422272
# At step: 5031, running average training error: 0.09312234011925025
# At step: 5032, running average training error: 0.08974376689953774
# At step: 5033, running average training error: 0.10446105637815059
# At step: 5034, running average training error: 0.10345515257259046
# At step: 5035, running average training error: 0.0978739844163595
# At step: 5036, running average training error: 0.09907456446414427
# At step: 5037, running average training error: 0.0931541721488349
# At step: 5038, running average training error: 0.08481742491178534
# At step: 5039, running average training error: 0.08068062635492773
# At step: 5040, running average training error: 0.07674838040126508
# At step: 5041, running average training error: 0.08545463861154179
# At step: 5042, running average training error: 0.08706869362820328
# At step: 5043, running average training error: 0.08481756231890744
# At step: 5044, running average training error: 0.07734464674068973
# At step: 5045, running average training error: 0.08479066304896372
# At step: 5046, running average training error: 0.08226285539912603
# At step: 5047, running average training error: 0.09837355405975493
# At step: 5048, running average training error: 0.10039166773358627
# At step: 5049, running average training error: 0.09329375349348733
# At step: 5050, running average training error: 0.08734095782319315
# At step: 5051, running average training error: 0.08265509222208649
# At step: 5052, running average training error: 0.0827979493995125
# At step: 5053, running average training error: 0.08615145807360708
# At step: 5054, running average training error: 0.08702892651704662
# At step: 5055, running average training error: 0.08986416026074512
# At step: 5056, running average training error: 0.08959608549672227
# At step: 5057, running average training error: 0.09283454075604508
# At step: 5058, running average training error: 0.09681810259355644
# At step: 5059, running average training error: 0.09531300691209987
# At step: 5060, running average training error: 0.09716367368549882
# At step: 5061, running average training error: 0.10022902120922353
# At step: 5062, running average training error: 0.09682763007552428
# At step: 5063, running average training error: 0.1000807680763815
# At step: 5064, running average training error: 0.09615935901491912
# At step: 5132, running average training error: 0.108047689574803
# At step: 5133, running average training error: 0.10746080808836035
# At step: 5134, running average training error: 0.11156882281675562
# At step: 5135, running average training error: 0.10696230183175325
# At step: 5136, running average training error: 0.09928935464495256
# At step: 5137, running average training error: 0.10164473645058963
# At step: 5138, running average training error: 0.10709594399426939
# At step: 5139, running average training error: 0.10168239618689001
# At step: 5140, running average training error: 0.09486885645316318
# At step: 5141, running average training error: 0.08968403124958442
# At step: 5142, running average training error: 0.08823185686802136
# At step: 5143, running average training error: 0.0882917657860689
# At step: 5144, running average training error: 0.08647557188120374
# At step: 5145, running average training error: 0.08897314854640527
# At step: 5146, running average training error: 0.09851814810989189
# At step: 5147, running average training error: 0.09833277674485878
# At step: 5148, running average training error: 0.09628044960460264
# At step: 5149, running average training error: 0.1042153325580318
# At step: 5150, running average training error: 0.10367340688901962
# At step: 5151, running average training error: 0.10377243075483007
# At step: 5152, running average training error: 0.10111039063331317
# At step: 5153, running average training error: 0.0976856711539673
# At step: 5154, running average training error: 0.09100558233757444
# At step: 5155, running average training error: 0.08422364826328231
# At step: 5156, running average training error: 0.08346830428435581
# At step: 5157, running average training error: 0.08416802496608812
# At step: 5158, running average training error: 0.08408359187310978
# At step: 5159, running average training error: 0.08054182587634359
# At step: 5160, running average training error: 0.08218411886986741
# At step: 5161, running average training error: 0.08239345947764913
# At step: 5162, running average training error: 0.08031198042701189
# At step: 5163, running average training error: 0.08426599459894922
# At step: 5164, running average training error: 0.08066376646833902
# At step: 5165, running average training error: 0.07817458396835643
# At step: 5166, running average training error: 0.07774473668780905
# At step: 5167, running average training error: 0.08963946412975839
# At step: 5168, running average training error: 0.09362596201466028
# At step: 5169, running average training error: 0.09019072729361301
# At step: 5170, running average training error: 0.08858385833365227
# At step: 5171, running average training error: 0.08551576507719952
# At step: 5172, running average training error: 0.08060164102720863
# At step: 5173, running average training error: 0.07812666243664235
# At step: 5174, running average training error: 0.07176317027315161
# At step: 5175, running average training error: 0.07938922800977823
# At step: 5176, running average training error: 0.08332150074188677
# At step: 5177, running average training error: 0.08323300464265826
# At step: 5178, running average training error: 0.08247315922740393
# At step: 5179, running average training error: 0.08677284725280847
# At step: 5180, running average training error: 0.09171457360278061
# At step: 5181, running average training error: 0.10087355539799102
# At step: 5182, running average training error: 0.10232515518209112
# At step: 5183, running average training error: 0.10705532744921224
# At step: 5184, running average training error: 0.11112309278246452
# At step: 5185, running average training error: 0.10955561911797956
# At step: 5186, running average training error: 0.10525497202664523
# At step: 5187, running average training error: 0.1018970897377637
# At step: 5188, running average training error: 0.10196311615755779
# At step: 5189, running average training error: 0.09765943043298471
# At step: 5190, running average training error: 0.09516012085833153
# At step: 5191, running average training error: 0.08618837172019234
# At step: 5192, running average training error: 0.08190448312299103
# At step: 5193, running average training error: 0.08818990448576433
# At step: 5194, running average training error: 0.09301013902423161
# At step: 5195, running average training error: 0.09624271915933137
# At step: 5196, running average training error: 0.0907606140425556
# At step: 5197, running average training error: 0.08965964396101149
# At step: 5198, running average training error: 0.08528739498630374
# At step: 5199, running average training error: 0.08492430243955357
# At step: 5200, running average training error: 0.08992664545403045
# At step: 5201, running average training error: 0.08277219303527486
# At step: 5202, running average training error: 0.08968018167097655
# At step: 5203, running average training error: 0.0853798535831445
# At step: 5204, running average training error: 0.0915543523128527
# At step: 5205, running average training error: 0.08471127178917114
# At step: 5206, running average training error: 0.08717445405747952
# At step: 5207, running average training error: 0.09512983026157515
# At step: 5208, running average training error: 0.09007958886706041
# At step: 5209, running average training error: 0.09359584889736582
# At step: 5210, running average training error: 0.10044304116347237
# At step: 5211, running average training error: 0.0957402897368046
# At step: 5212, running average training error: 0.09064414509779109
# At step: 5213, running average training error: 0.0881355554187484
# At step: 5214, running average training error: 0.09805257480909257
# At step: 5215, running average training error: 0.10580589846286799
# At step: 5216, running average training error: 0.1123503083738843
# At step: 5217, running average training error: 0.11183298157041831
# At step: 5218, running average training error: 0.1126994742966809
# At step: 5219, running average training error: 0.10912074952098565
# At step: 5220, running average training error: 0.10215181478223931
# At step: 5221, running average training error: 0.10671189244613592
# At step: 5222, running average training error: 0.10574724412488352
# At step: 5223, running average training error: 0.1029454841428991
# At step: 5224, running average training error: 0.10357877886604822
# At step: 5225, running average training error: 0.1074839759630916
# At step: 5226, running average training error: 0.1168892818945851
# At step: 5227, running average training error: 0.10976075755091758
# At step: 5228, running average training error: 0.11087585050265406
# At step: 5229, running average training error: 0.1110939707544506
# At step: 5230, running average training error: 0.10482303216173164
# At step: 5231, running average training error: 0.10098032484447936
# At step: 5232, running average training error: 0.10473466888989587
# At step: 5233, running average training error: 0.09858838543266318
# At step: 5234, running average training error: 0.09548519978788828
# At step: 5235, running average training error: 0.08765601270658767
# At step: 5236, running average training error: 0.0892211261691982
# At step: 5237, running average training error: 0.09135074195228178
# At step: 5238, running average training error: 0.08833320981172925
# At step: 5239, running average training error: 0.08423249071925439
# At step: 5240, running average training error: 0.08289465821862939
# At step: 5241, running average training error: 0.09146950180090671
# At step: 5242, running average training error: 0.08316550838142103
# At step: 5243, running average training error: 0.08194579164298968
# At step: 5244, running average training error: 0.07957343797271885
# At step: 5245, running average training error: 0.08065458065588696
# At step: 5246, running average training error: 0.08009490695528781
# At step: 5247, running average training error: 0.07778167922989178
# At step: 5248, running average training error: 0.08079794938857011
# At step: 5249, running average training error: 0.08093591821913304
# At step: 5250, running average training error: 0.08373263444490436
# At step: 5251, running average training error: 0.08157218266876626
# At step: 5252, running average training error: 0.07940785409222478
# At step: 5253, running average training error: 0.0863097842899446
# At step: 5254, running average training error: 0.08544569907294258
# At step: 5255, running average training error: 0.08411935058643355
# At step: 5256, running average training error: 0.07805028574397699
# At step: 5257, running average training error: 0.07688174571641379
# At step: 5258, running average training error: 0.07044597583846436
# At step: 5259, running average training error: 0.06744015093542548
# At step: 5260, running average training error: 0.06512050956293593
# At step: 5261, running average training error: 0.06226201188682083
# At step: 5262, running average training error: 0.07329572698219619
# At step: 5263, running average training error: 0.0714883018123067
# At step: 5264, running average training error: 0.07034447800819606
# At step: 5265, running average training error: 0.06893587481160757
# At step: 5266, running average training error: 0.07269209156465377
# At step: 5402, running average training error: 0.09179882833808903
# At step: 5403, running average training error: 0.09077642012599763
# At step: 5404, running average training error: 0.08967649735795707
# At step: 5405, running average training error: 0.08827497874338089
# At step: 5406, running average training error: 0.09015962257485077
# At step: 5407, running average training error: 0.09120209172712063
# At step: 5408, running average training error: 0.08715048960823137
# At step: 5409, running average training error: 0.08722902592981266
# At step: 5410, running average training error: 0.08608804870736968
# At step: 5411, running average training error: 0.08401888062412848
# At step: 5412, running average training error: 0.07900643454747941
# At step: 5413, running average training error: 0.08321588591399856
# At step: 5414, running average training error: 0.08448420535735375
# At step: 5415, running average training error: 0.09394775068150385
# At step: 5416, running average training error: 0.09733438444321194
# At step: 5417, running average training error: 0.09253379925663104
# At step: 5418, running average training error: 0.09217334198600054
# At step: 5419, running average training error: 0.09869286961736069
# At step: 5420, running average training error: 0.10101132085921916
# At step: 5421, running average training error: 0.1051633888894124
# At step: 5422, running average training error: 0.10282935685665179
# At step: 5423, running average training error: 0.0983369816555883
# At step: 5424, running average training error: 0.1060462968427388
# At step: 5425, running average training error: 0.09686254931726423
# At step: 5426, running average training error: 0.09482572909311822
# At step: 5427, running average training error: 0.10895491475456447
# At step: 5428, running average training error: 0.10345352206233756
# At step: 5429, running average training error: 0.09615494121294964
# At step: 5430, running average training error: 0.09474946165753245
# At step: 5431, running average training error: 0.08925341205980691
# At step: 5432, running average training error: 0.08860262644298854
# At step: 5433, running average training error: 0.08781781852142466
# At step: 5434, running average training error: 0.09113720010122221
# At step: 5435, running average training error: 0.09022947894681338
# At step: 5436, running average training error: 0.0864788100667458
# At step: 5437, running average training error: 0.08573762581908008
# At step: 5438, running average training error: 0.08029266540685817
# At step: 5439, running average training error: 0.0895900309466385
# At step: 5440, running average training error: 0.09338216240213834
# At step: 5441, running average training error: 0.10052891562689992
# At step: 5442, running average training error: 0.09764786849575895
# At step: 5443, running average training error: 0.09438695056077084
# At step: 5444, running average training error: 0.09678591731901288
# At step: 5445, running average training error: 0.10625148412777237
# At step: 5446, running average training error: 0.10713330933087535
# At step: 5447, running average training error: 0.11248696352930672
# At step: 5448, running average training error: 0.11050597880063727
# At step: 5449, running average training error: 0.11275083070257835
# At step: 5450, running average training error: 0.10814672220751967
# At step: 5451, running average training error: 0.11226002153122225
# At step: 5452, running average training error: 0.11282883849551864
# At step: 5453, running average training error: 0.1027309632699369
# At step: 5454, running average training error: 0.1059128984680725
# At step: 5455, running average training error: 0.10004292520893249
# At step: 5456, running average training error: 0.1018692724497023
# At step: 5457, running average training error: 0.09920882494107133
# At step: 5458, running average training error: 0.09272614531807256
# At step: 5459, running average training error: 0.10426258771479079
# At step: 5460, running average training error: 0.1104179980328573
# At step: 5461, running average training error: 0.12256475895337995
# At step: 5462, running average training error: 0.11293699106403506
# At step: 5463, running average training error: 0.10454535727694295
# At step: 5464, running average training error: 0.09657423732980505
# At step: 5465, running average training error: 0.09402184476923686
# At step: 5466, running average training error: 0.0931971565100856
# At step: 5467, running average training error: 0.08811885403500924
# At step: 5468, running average training error: 0.08311136217284597
# At step: 5604, running average training error: 0.0965348476612565
# At step: 5605, running average training error: 0.09492630529976445
# At step: 5606, running average training error: 0.09615796370480119
# At step: 5607, running average training error: 0.08850828808858091
# At step: 5608, running average training error: 0.09359522113922865
# At step: 5609, running average training error: 0.09717186873043585
# At step: 5610, running average training error: 0.10670488617163369
# At step: 5611, running average training error: 0.10411571195710097
# At step: 5612, running average training error: 0.10259866973082249
# At step: 5613, running average training error: 0.09476686117159623
# At step: 5614, running average training error: 0.09118558163720426
# At step: 5615, running average training error: 0.08878532941666062
# At step: 5616, running average training error: 0.09054354281739094
# At step: 5617, running average training error: 0.09316950349371338
# At step: 5618, running average training error: 0.09636563239389091
# At step: 5619, running average training error: 0.09865606387965224
# At step: 5620, running average training error: 0.09958826396778328
# At step: 5621, running average training error: 0.09912992566096612
# At step: 5622, running average training error: 0.10260235436039655
# At step: 5623, running average training error: 0.10160981361677329
# At step: 5624, running average training error: 0.09514594084248987
# At step: 5625, running average training error: 0.10239184546430259
# At step: 5626, running average training error: 0.09372345311987003
# At step: 5627, running average training error: 0.09525311873764303
# At step: 5628, running average training error: 0.10294286678732115
# At step: 5629, running average training error: 0.10283865024457241
# At step: 5630, running average training error: 0.10327703046247662
# At step: 5631, running average training error: 0.09762638037607958
# At step: 5632, running average training error: 0.09399128339725829
# At step: 5633, running average training error: 0.08893060056752324
# At step: 5634, running average training error: 0.08655762012712252
# At step: 5635, running average training error: 0.0884111310456296
# At step: 5636, running average training error: 0.08386140168283414
# At step: 5637, running average training error: 0.09024781466302703
# At step: 5638, running average training error: 0.08363146530413734
# At step: 5639, running average training error: 0.08754037501692483
# At step: 5640, running average training error: 0.08928695150219632
# At step: 5641, running average training error: 0.08349612169138652
# At step: 5642, running average training error: 0.09830048797661772
# At step: 5643, running average training error: 0.10369082844450576
# At step: 5644, running average training error: 0.09738646270402253
# At step: 5645, running average training error: 0.09528576168043072
# At step: 5646, running average training error: 0.08992705753095886
# At step: 5647, running average training error: 0.09192016639954008
# At step: 5648, running average training error: 0.09064177285224115
# At step: 5649, running average training error: 0.08734823049295388
# At step: 5650, running average training error: 0.0874281093753189
# At step: 5651, running average training error: 0.08494149118688546
# At step: 5652, running average training error: 0.08783002596088735
# At step: 5653, running average training error: 0.09174095900240839
# At step: 5654, running average training error: 0.08931710807295615
# At step: 5655, running average training error: 0.08122287440784508
# At step: 5656, running average training error: 0.0786777106769768
# At step: 5657, running average training error: 0.08421782189464413
# At step: 5658, running average training error: 0.08400032058013839
# At step: 5659, running average training error: 0.083508544214331
# At step: 5660, running average training error: 0.08001681358031046
# At step: 5661, running average training error: 0.08327927280136978
# At step: 5662, running average training error: 0.07787012507944552
# At step: 5663, running average training error: 0.07634611377361367
# At step: 5664, running average training error: 0.07263385998100663
# At step: 5665, running average training error: 0.07879021168814934
# At step: 5666, running average training error: 0.08454716004398294
# At step: 5667, running average training error: 0.09565253833351246
# At step: 5668, running average training error: 0.10671608797884072
# At step: 5669, running average training error: 0.1063535776236441
# At step: 5670, running average training error: 0.11133025808751659
# At step: 9984, running average training error: 0.08607607610685689
# At step: 9985, running average training error: 0.09430011967748901
# At step: 9986, running average training error: 0.09107537892757589
# At step: 9987, running average training error: 0.08928124017665873
# At step: 9988, running average training error: 0.08421608469204454
# At step: 9989, running average training error: 0.07941643485448124
# At step: 9990, running average training error: 0.08076914140566548
# At step: 9991, running average training error: 0.08432099274929719
# At step: 9992, running average training error: 0.09239666236806471
# At step: 9993, running average training error: 0.096351564726365
# At step: 9994, running average training error: 0.08861597815787615
# At step: 9995, running average training error: 0.09059511978285568
# At step: 9996, running average training error: 0.08916236928953414
# At step: 9997, running average training error: 0.0911959320833423
# At step: 9998, running average training error: 0.09417223627071361
# At step: 9999, running average training error: 0.10133942504364901
# At Epoch 9, validation error: 0.020496943249357854, validation accuracy 0.8783

# %% [markdown]
# We can also evaluate the network!

# %%
R = net.fwd(X[60000:60010,:])

for i in range(10):
  plt.imshow(np.reshape(X[60000 + i,:],(28,28)), cmap = 'gray')
  plt.show()
  print(R[i])
  print(np.argmax(R[i,:]))
# Out:
# [2.59022472e-05 5.14066538e-04 3.97120596e-04 3.06187954e-02
#  2.03478169e-03 3.75600394e-03 7.70346070e-08 9.43547680e-01
#  5.82567909e-07 5.01258079e-03]
# 7
# [6.37627408e-04 3.13524534e-03 4.98849452e-01 3.05877435e-02
#  3.83421597e-09 2.99661679e-05 4.20281532e-04 3.87850928e-06
#  3.39251322e-05 9.04560108e-05]
# 2
# [9.53235241e-06 9.99843914e-01 6.36750162e-06 1.74653849e-03
#  5.74819959e-07 1.07448493e-03 6.50961910e-06 1.35487376e-04
#  9.46797371e-06 6.63239867e-04]
# 1
# [9.19379990e-01 3.12852972e-04 6.94304802e-05 3.38898868e-03
#  4.82485830e-07 6.21450710e-04 2.26496958e-04 8.54549427e-05
#  1.05264935e-05 2.39439216e-03]
# 0
# [9.94048336e-07 1.02131025e-05 7.70884624e-05 4.68251994e-04
#  9.61320740e-01 7.41492941e-04 5.76144147e-05 3.11760799e-03
#  3.41076367e-05 8.50859016e-03]
# 4
# [3.93801346e-05 9.99848764e-01 3.97396499e-05 5.05669599e-03
#  5.70424881e-07 1.35536823e-04 2.19222530e-06 2.08976816e-04
#  6.65006292e-06 6.64059446e-04]
# 1
# [6.17125199e-06 1.51960828e-03 4.43147577e-06 1.23222299e-03
#  1.38922318e-01 1.34375395e-02 1.67497779e-06 7.43093802e-02
#  9.94127420e-05 3.37441157e-02]
# 4
# [4.66135475e-06 5.15399241e-03 7.29736694e-06 1.32262500e-02
#  8.65260410e-04 2.51814802e-04 1.96679638e-07 1.26198693e-03
#  2.29410057e-04 9.97239684e-01]
# 9
# [2.25363869e-04 4.22408771e-05 9.81111810e-06 2.23314227e-03
#  8.29701378e-04 4.55800853e-02 4.11596709e-02 7.61447269e-06
#  3.48492907e-04 2.23464621e-02]
# 5
# [6.64957526e-05 3.55515322e-03 3.00409496e-06 1.21753589e-03
#  7.10237463e-03 1.92443698e-04 1.53024594e-06 1.57469928e-03
#  4.98492620e-04 9.96818171e-01]
# 9
